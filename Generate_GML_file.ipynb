# %% [markdown]
# # Generate a GML file for network analysis
#
# This notebook accompanies
#
# > Hall, M (2017). Three data analytics party tricks. _The Leading Edge_ **36** (3).
#
# I am exchanging data with `NetworkX` (the graph analysis package) in [**Graph Modelling Language**](https://en.wikipedia.org/wiki/Graph_Modelling_Language) (not to be confused with Graph Markup Language, which is a dialect of XML).
#
# This is the first time I've met this format so I am going to do this in a pretty naïve way.

# %%
import pandas as pd
import unidecode
import re
from collections import defaultdict
from itertools import combinations

# %% [markdown]
# Read the file I made from the full bibliographic database. It is a list of lists, in which each inner list is a list of authors for a since paper. The list-of-lists is stored as a Python 'pickle' file. I'm reading it into Pandas, which may or may not turn out to be convenient later.

# %%
ds = pd.read_pickle('data/authors.pkl')

# %%
ds.head()
# Out:
# 7566    [M. N. Nabighian, V. J. S. Grauch, R. O. Hanse...
# 6095             [Yoshio Ueda, Ryuji Kubota, Jiro Segawa]
# 3289                      [Philip S. Schultz, August Lau]
# 4218                      [Norman S. Neidell, Neal Berry]
# 7167                       [Hengchang Dai, Xiang-Yang Li]
# Name: authors, dtype: object

# %% [markdown]
# ## Define some preprocessing
#
# Dealing with names from a database is almost always trickjy. There are weird characters (most of which I should already have dealt with, outside of this notebook), and variations in spelling for a given person's name. Some of these variations are very hard to deal with, so we're not going to end up with perfect data.
#
# This is a bit hacky...
#
# - To avoid confusing `L Lines` with `Larry Lines` and `LR Lines` and `Laurence R Lines`, etc, I am going to keep only initials plus surnames: `LLines`.
# - I also want to maintain bits of surnames like 'van de', so `MVanDerBaan` for `MirkoVanDerBaan`.
# - However, if a surname has 4 or fewer characters, I will keep the full name, so `MattHall` for `Matt Hall` (otherwise we get a lot of collisions on short, common names like `Li`).

# %%
def process_name(name):
    name = unidecode.unidecode(name).title()
    name = re.sub(r"[-\.']", r'', name).strip()
    bits = name.split()
    for bit in bits:
        extra = ''
        if bit in ['Van', 'Von', 'Der', 'De', 'Da', 'Di', 'Du', 'Della', 'Dos', 'Al', 'El', 'La', 'Le', 'St']:
            extra += bit
    if len(bits[-1]) < 5:
        return bits[0] + extra + bits[-1]
    return name[0] + extra + bits[-1]

# %% [markdown]
# ## Collect author data
#
# We'll use this as we loop over the dataframe (yes, there's probably a much better way to do this!).
#
# The GLM format has two parts: a node list, and an edge list.
#
# Node list part:
#
#     node [
#       id 72
#       label "Toussaint"
#     ]
#     node [
#       id 73
#       label "Child1"
#     ]
#
# Edge list part:
#
#     edge [
#       source 19
#       target 17
#       value 4
#     ]
#     edge [
#       source 19
#       target 18
#       value 4
#     ]
#
# Let's make a dict first, like:
#
#     { Brown: {Smith: 1, Jones: 3, Einstein: 23},
#       Smith: {Brown: 1, Doe: 3},
#     }
#
# Undirected so we can just use combinations:

# %%
auth_nodes = []
auth_edges = defaultdict(lambda: defaultdict(int))

for auth_list in ds:
    
    # Preprocess
    auths = sorted(process_name(auth) for auth in auth_list)
    auth_nodes += auths

    # Build edge dict.
    combs = combinations(auths, 2)
    for (src, trgt) in combs:
        auth_edges[src][trgt] += 1

auth_nodes = list(set(auth_nodes))

# %%
auth_nodes
# Out:
# ['CReeves',
#  'SBiehler',
#  'SamuelKarp',
#  'JSchleicher',
#  'RWatts',
#  'JSchmoker',
#  'DaleCox',
#  'GSimmons',
#  'CPower',
#  'RGodfrey',
#  'LKonstantaki',
#  'DaniOr',
#  'RHorne',
#  'IBeresnev',
#  'JWong',
#  'HWashburn',
#  'DBlair',
#  'MGreenhalgh',
#  'APoikonen',
#  'GerhardLukk',
#  'JJohnson',
#  'AQuarteroni',
#  'QingyunDiDi',
#  'JKoski',
#  'JBerryhill',
#  'ABarthelmes',
#  'JAllingham',
#  'PGarossino',
#  'DAnderson',
#  'MJones',
#  'GRice',
#  'RLopes',
#  'DMagnier',
#  'WMcguinness',
#  'JPatch',
#  'ZengliDuDu',
#  'CCamerlynck',
#  'MZhang',
#  'LBorgman',
#  'DGough',
#  'CVaughan',
#  'DKinman',
#  'SAltaner',
#  'KLau',
#  'MBuonora',
#  'MHewitt',
#  'RobertBaum',
#  'SUpadhyay',
#  'BSeymour',
#  'ZhengpingLiu',
#  'LBerryman',
#  'AHusseiny',
#  'EKelly',
#  'YingjieGao',
#  'ECaspari',
#  'ABeck',
#  'ArmandoSena',
#  'EmilyFay',
#  'JAllsop',
#  'CanYang',
#  'GYadav',
#  'JCarvalho',
#  'XiangDuDu',
#  'GNover',
#  'JohnBeck',
#  'AndrejBona',
#  'ZhanxiangHe',
#  'WFilipo',
#  'JorgenPihl',
#  'OPedersen',
#  'AKuvshinov',
#  'SThiel',
#  'JTrier',
#  'DAdkinsHeljeson',
#  'CDresbach',
#  'MBeiki',
#  'KGomes',
#  'GGribler',
#  'HauWeiZhou',
#  'RSteinhoff',
#  'YMiyazaki',
#  'RVincent',
#  'KDieter',
#  'CVuik',
#  'RPeterson',
#  'LDemkowicz',
#  'DRhodes',
#  'KAytun',
#  'LTucker',
#  'NRykhlinski',
#  'RGraebner',
#  'AGregory',
#  'EOnegova',
#  'BGelchinsky',
#  'DavidHart',
#  'RBenson',
#  'OLovera',
#  'MKrohn',
#  'ShaharArad',
#  'EStatham',
#  'ZhenYang',
#  'LMorrison',
#  'SWitsker',
#  'JungkyunShin',
#  'EOblow',
#  'NaFan',
#  'BinLiu',
#  'JGrant',
#  'RGhose',
#  'DAdams',
#  'BinghengYuan',
#  'JoostNeut',
#  'CElvidge',
#  'JianjunZeng',
#  'ALegchenko',
#  'AVladimirsky',
#  'RRenaut',
#  'TDouglas',
#  'SChung',
#  'HeeKim',
#  'HaoGuo',
#  'SBrowning',
#  'WCurry',
#  'HWerner',
#  'RMeek',
#  'WLowrie',
#  'EWinniski',
#  'SandraVega',
#  'YongenCai',
#  'HEicken',
#  'RossGunn',
#  'VKumar',
#  'CMiller',
#  'WMcelroy',
#  'JTaranik',
#  'AForster',
#  'MadelineLee',
#  'EWescott',
#  'WUtama',
#  'ELanda',
#  'EPervago',
#  'FHilterman',
#  'ILongman',
#  'PAdler',
#  'GHocht',
#  'IMorozov',
#  'JHeggblom',
#  'SeungGooKang',
#  'DBarnes',
#  'OOncken',
#  'OShushakov',
#  'ZhenyaZhu',
#  'MSkold',
#  'HPickett',
#  'HTewari',
#  'LWhite',
#  'AnaAbad',
#  'YongMa',
#  'AVerdel',
#  'JXiang',
#  'IMuller',
#  'AClark',
#  'RCarroll',
#  'DDatta',
#  'KSegeth',
#  'BSiemon',
#  'LNicoletis',
#  'MCampillo',
#  'LGochioco',
#  'VThyssenBornemisza',
#  'DBlankenship',
#  'GStuart',
#  'DBaldwin',
#  'GRobertson',
#  'TingEnFan',
#  'KKlaus',
#  'AZemanian',
#  'WKellogg',
#  'KLange',
#  'JSchufle',
#  'KHayley',
#  'EAnderson',
#  'EtienneRey',
#  'SNicoletis',
#  'JFinol',
#  'MTempleton',
#  'HuJin',
#  'WLutter',
#  'NCanitez',
#  'HAshraf',
#  'AAhmadifard',
#  'PCunningham',
#  'THall',
#  'BRao',
#  'JLiard',
#  'ADeighan',
#  'KwangjinYoon',
#  'NNahi',
#  'ShuminChen',
#  'ChenLi',
#  'DRevelo',
#  'TPoole',
#  'MStudinger',
#  'TRichards',
#  'JeongminYu',
#  'ACrosta',
#  'SHautot',
#  'EGonzalo',
#  'ADuijndam',
#  'PGoupillaud',
#  'RBisdorf',
#  'JDumay',
#  'VLabson',
#  'EToewe',
#  'GPerez',
#  'SYaskevich',
#  'JSkinner',
#  'WFletcher',
#  'MathiasFink',
#  'HJaramillo',
#  'GDuncan',
#  'WHorner',
#  'LAllen',
#  'EForte',
#  'BHoffe',
#  'YuxinWu',
#  'HuiWang',
#  'QianZhao',
#  'GuangQi',
#  'FRenalier',
#  'CCorry',
#  'JBuchner',
#  'HCruts',
#  'EAbdelrahman',
#  'PByerly',
#  'SBilinsky',
#  'PHenkart',
#  'WBurnett',
#  'KNakayama',
#  'DavidPai',
#  'JSinton',
#  'EOrellana',
#  'IPanea',
#  'SCalkin',
#  'EMaeland',
#  'OAgudo',
#  'NiuWei',
#  'COfficer',
#  'AGallois',
#  'CEngland',
#  'MVoltolini',
#  'WFarren',
#  'WKeys',
#  'DWantland',
#  'NHargreaves',
#  'AAsnaashari',
#  'NNAtienza',
#  'MDabas',
#  'PNyegaard',
#  'VDruskin',
#  'HWinkler',
#  'DaxingWang',
#  'NKamath',
#  'SPehrsson',
#  'JOsoba',
#  'LeeHunt',
#  'ABasokur',
#  'WStone',
#  'SArcone',
#  'MPorsani',
#  'ZaiTianMa',
#  'TPlona',
#  'MSugihara',
#  'LMyer',
#  'ARoberts',
#  'LAltissimo',
#  'TGamble',
#  'ETrevino',
#  'AlfonsoI',
#  'SAssous',
#  'JZiagos',
#  'LIvanhoe',
#  'DMcconnell',
#  'REvans',
#  'ADaynes',
#  'ChuanhuiLi',
#  'KaiyunLuo',
#  'RNisle',
#  'ShuangLiu',
#  'ALeblanc',
#  'NanxunDai',
#  'DaeungYoon',
#  'JFitter',
#  'TFurumura',
#  'FAngona',
#  'JDiebold',
#  'ULorang',
#  'InKyCho',
#  'WIsherwood',
#  'JODonnell',
#  'OAlhagan',
#  'LPankratz',
#  'WGreen',
#  'ChengliangFan',
#  'MZhdanov',
#  'MJegen',
#  'LanboLiu',
#  'WeinanWang',
#  'APidlisecky',
#  'JSharpe',
#  'MChan',
#  'YShteyn',
#  'TianfengWan',
#  'AKobrunov',
#  'LZimmerman',
#  'FCiabarri',
#  'DKao',
#  'LPakiser',
#  'KCoyner',
#  'GHouseman',
#  'DJayawickreme',
#  'ACastoro',
#  'SPullammanappallil',
#  'AHanssen',
#  'NSundararajan',
#  'SBreiner',
#  'LBotterJensen',
#  'LiangSun',
#  'BaofengTian',
#  'RRaffalovich',
#  'TMurray',
#  'ALeykam',
#  'CBaumann',
#  'LSkopintseva',
#  'RichardFaas',
#  'AZhubayev',
#  'DJupp',
#  'JungKim',
#  'RRomijn',
#  'MClennell',
#  'VFiore',
#  'WWendt',
#  'WHawes',
#  'GTurkiyyah',
#  'JMoore',
#  'CDennis',
#  'THildenbrand',
#  'JDvorkin',
#  'GCooper',
#  'JamesWait',
#  'DJohnson',
#  'JeffreyWynn',
#  'RPawlowski',
#  'JCharbucinski',
#  'SCao',
#  'CRushlow',
#  'RichardWold',
#  'EDougherty',
#  'NigelRees',
#  'FernandoDias',
#  'MLintern',
#  'RDumont',
#  'RGreaves',
#  'NVergo',
#  'PStanford',
#  'TLowry',
#  'THenyey',
#  'StefanBunz',
#  'JRezaie',
#  'RLankston',
#  'JHannila',
#  'RichardFox',
#  'EDeridder',
#  'SHanafy',
#  'ByungKooHyun',
#  'HungTran',
#  'EMercado',
#  'LChiao',
#  'DBonar',
#  'RPittman',
#  'RShaw',
#  'FGuspi',
#  'MRabinovich',
#  'MMatos',
#  'MMarkov',
#  'RachelWood',
#  'SWilliamsStroud',
#  'ALebedev',
#  'KOwusu',
#  'KalachandSain',
#  'CKimball',
#  'AMisbah',
#  'PMihalffy',
#  'OLogn',
#  'LUhrig',
#  'DEllis',
#  'MWathelet',
#  'BingbingSun',
#  'HBrown',
#  'JMacnae',
#  'AWitten',
#  'CaCa',
#  'RPhinney',
#  'YueWang',
#  'KHedlin',
#  'GMcguckin',
#  'EEckhardt',
#  'HPaasche',
#  'LWeihermuller',
#  'MelchiorGrab',
#  'KAktas',
#  'MTrani',
#  'WBeatty',
#  'EZinni',
#  'GuanWang',
#  'XiaoxiaXu',
#  'MDelescluse',
#  'TongningYang',
#  'RolandPail',
#  'NFrearson',
#  'RParker',
#  'NArihara',
#  'ERothert',
#  'MMajdanski',
#  'YAbdelhady',
#  'AlfredoLeon',
#  'JBarongo',
#  'BDashwood',
#  'PShamsipour',
#  'TBurkhart',
#  'HongbingLi',
#  'AKotz',
#  'JStafleu',
#  'YunfengGao',
#  'RNorris',
#  'KErnstson',
#  'JFitton',
#  'YRicard',
#  'SMittal',
#  'KMatson',
#  'SHummerMiller',
#  'MHoppmann',
#  'TheoMary',
#  'MDobrin',
#  'SKlemperer',
#  'YAshida',
#  'WCarey',
#  'HButtlar',
#  'DCasper',
#  'JHedditch',
#  'HGerhards',
#  'KErickson',
#  'QingxinSu',
#  'LBertelli',
#  'ZXiong',
#  'GPalacky',
#  'RBurnett',
#  'AlfredWolf',
#  'RE',
#  'AUstra',
#  'WeiKang',
#  'HCollier',
#  'JDuval',
#  'PeiJuShih',
#  'GLoper',
#  'PGolodoniuc',
#  'JIffland',
#  'ABarnhoorn',
#  'ShikunDai',
#  'AThomasBetts',
#  'JLyrio',
#  'KennethBube',
#  'COrstrand',
#  'SMartins',
#  'PabitraSen',
#  'DRaymer',
#  'JSchuelke',
#  'MChmiel',
#  'PMudra',
#  'LKnauer',
#  'LEsteban',
#  'ILonardelli',
#  'BFouke',
#  'MVembusubramanian',
#  'MBecquey',
#  'ZGuang',
#  'DWhite',
#  'FCampbell',
#  'PMunoz',
#  'JIrving',
#  'AshwaniDev',
#  'PPetrov',
#  'IZietz',
#  'OAhmed',
#  'PhilAnno',
#  'PMazumdar',
#  'JRosenbaum',
#  'ACorreia',
#  'ARosa',
#  'CMueller',
#  'FPress',
#  'MMalamphy',
#  'JHalpenny',
#  'PRicarte',
#  'BCouzensSchultz',
#  'MHoversten',
#  'MBest',
#  'MPattantyusA',
#  'APrugger',
#  'JClough',
#  'DPatterson',
#  'YSheng',
#  'MirkoBaan',
#  'FMulargia',
#  'JCoggon',
#  'SSquires',
#  'MDobroka',
#  'MaojinTan',
#  'SNakagawa',
#  'LOngkiehong',
#  'BVogelaar',
#  'WYingXiang',
#  'JVrbancich',
#  'LBorcea',
#  'DongWang',
#  'CaiLiu',
#  'YufeiXi',
#  'MDogan',
#  'ADziewonski',
#  'NDiamanti',
#  'MBarbier',
#  'AlwynRoss',
#  'FNguyen',
#  'TPratt',
#  'MeixiaGeng',
#  'ESammel',
#  'ChaoMa',
#  'APadilha',
#  'JLopez',
#  'EMcnatt',
#  'BHawley',
#  'AGhorbani',
#  'JSmidt',
#  'AHsui',
#  'AWagner',
#  'PDequirez',
#  'FMcgehee',
#  'TingFanDai',
#  'BDamiata',
#  'HFujiwara',
#  'CTrejo',
#  'JHodgkinson',
#  'GTristano',
#  'HHamid',
#  'DBrown',
#  'FKalantzis',
#  'HSagoci',
#  'BFahmy',
#  'RuoWang',
#  'KPennybaker',
#  'AWijngaarden',
#  'JHughson',
#  'RMoore',
#  'PMartin',
#  'MHolzman',
#  'RErickson',
#  'ANguyen',
#  'SRondenay',
#  'STheophanis',
#  'MFliedner',
#  'GBoitnott',
#  'JSchneider',
#  'CCorbato',
#  'YShinozaki',
#  'MPirrone',
#  'JianhuaLi',
#  'MCochran',
#  'HBoyd',
#  'ALesage',
#  'JRamosMartinez',
#  'RHammond',
#  'BMurty',
#  'TLloyd',
#  'MarkOlm',
#  'PMenezes',
#  'CMacdonald',
#  'GNoonan',
#  'MAnder',
#  'DRamakrishnan',
#  'CSwartz',
#  'JClippard',
#  'TKoulomzine',
#  'MHolschneider',
#  'VFarra',
#  'RuofeiLiu',
#  'ShengkaiZhao',
#  'SFontes',
#  'WHoneyman',
#  'VTuncer',
#  'YiNi',
#  'TQuarta',
#  'GMangan',
#  'XiumianHu',
#  'LixiaZhi',
#  'LelandLong',
#  'RSpecht',
#  'QingxingQi',
#  'NingYuan',
#  'DHilliker',
#  'GHodlur',
#  'OTiapkina',
#  'UmeshDas',
#  'LTsang',
#  'RobertMink',
#  'BWitten',
#  'POkoye',
#  'KHelbig',
#  'RPohly',
#  'RSprik',
#  'HaitaoHou',
#  'TMokhtar',
#  'HongmeiCao',
#  'WStephenson',
#  'MWyllie',
#  'KVanneste',
#  'THermans',
#  'ISomerton',
#  'FJones',
#  'IBrandt',
#  'WeiliLi',
#  'PLelievre',
#  'HHenson',
#  'EKoivisto',
#  'SUhlemann',
#  'MBevis',
#  'BFroment',
#  'JGallop',
#  'PMathieu',
#  'JRezkalla',
#  'KPayne',
#  'EShuck',
#  'DiYang',
#  'EAuken',
#  'JGestel',
#  'YMukuhira',
#  'RRau',
#  'HMansour',
#  'YiboWang',
#  'RSolbau',
#  'ASmith',
#  'MFaust',
#  'HTejadaFlores',
#  'ZDvorak',
#  'EHaber',
#  'MHouben',
#  'MMohammadzadeh',
#  'ANovais',
#  'HTieman',
#  'RGood',
#  'FLlera',
#  'HanqingLiu',
#  'QiZhou',
#  'MKabir',
#  'SimonHook',
#  'PRasolofosaon',
#  'DMorgan',
#  'TLafehr',
#  'JMimoun',
#  'OBarkved',
#  'MTouati',
#  'SHaines',
#  'UTinivella',
#  'SiweiLi',
#  'JHrabe',
#  'GuangyaoWu',
#  'HuaWeiZhou',
#  'TShugart',
#  'DReiter',
#  'JTittman',
#  'GVannaroni',
#  'JWhile',
#  'DWalsh',
#  'CHayward',
#  'XinhuaSun',
#  'EBallantyne',
#  'AndrewChan',
#  'EMuyzert',
#  'EMundry',
#  'CWotorson',
#  'AKudarova',
#  'BRummerfield',
#  'AOgilvy',
#  'LStegena',
#  'DPitcher',
#  'ILerche',
#  'GBishop',
#  'MPurucker',
#  'MWhitelaw',
#  'SYordkayhun',
#  'ZhongXiaoLi',
#  'GWhite',
#  'RMansfield',
#  'AndyWard',
#  'RGerdes',
#  'TProbert',
#  'NOHara',
#  'MAmaya',
#  'RobertoRege',
#  'JLeconte',
#  'ChengYin',
#  'MQuarles',
#  'CCalderonMac',
#  'DReynolds',
#  'KBeeney',
#  'RMellors',
#  'JGeertsma',
#  'GyeChunCho',
#  'YuchunWang',
#  'KerryKey',
#  'DominicKao',
#  'WJohnson',
#  'GCavuoto',
#  'GQuirogaGoode',
#  'JSass',
#  'RSingh',
#  'KChambers',
#  'JohnVoon',
#  'AAbubakar',
#  'TIngemanNielsen',
#  'JKrebs',
#  'DMorris',
#  'AAugustin',
#  'DKomatitsch',
#  'JGlover',
#  'JBruso',
#  'TerjeDahl',
#  'DPatella',
#  'JKauahikaua',
#  'DThiel',
#  'YKvistedal',
#  'DGoertz',
#  'SHarris',
#  'DMitchell',
#  'RDimitrakopoulos',
#  'DHinkley',
#  'KBurson',
#  'TRozsa',
#  'RStrahilevitz',
#  'ChengfangYin',
#  'IMoore',
#  'APires',
#  'DMasne',
#  'JMitchell',
#  'ASilva',
#  'RMeyer',
#  'MingqiuLuo',
#  'RLebras',
#  'HMccarver',
#  'LiquanQiu',
#  'KHansen',
#  'BBonner',
#  'KainanWang',
#  'APica',
#  'MMaraschini',
#  'MChinnery',
#  'RSlusarczyk',
#  'LloydWest',
#  'BinWang',
#  'PeterVass',
#  'DDroschak',
#  'SPanda',
#  'RVersteeg',
#  'KSriram',
#  'DNtarlagiannis',
#  'EGomezTrevino',
#  'DFinnegan',
#  'JieQi',
#  'OLavialle',
#  'DMonteverde',
#  'JTakekawa',
#  'CHardwick',
#  'EHolden',
#  'RHobbs',
#  'MZaslavsky',
#  'AStovas',
#  'UAlbertin',
#  'DSeifer',
#  'GMelickian',
#  'RBortfeld',
#  'DRockwell',
#  'ZhiyangWang',
#  'YouliQuan',
#  'MLandschulze',
#  'LSchmid',
#  'JuefuWang',
#  'FHinrichs',
#  'IMason',
#  'RHaacke',
#  'IWon',
#  'MTanter',
#  'SClark',
#  'JRobertsson',
#  'AGangi',
#  'ABelani',
#  'PChroston',
#  'DDrahos',
#  'BFrignet',
#  'NDyaur',
#  'WMclamore',
#  'JDaniels',
#  'JWashbourne',
#  'LGardner',
#  'QiningFeng',
#  'ShengwenJin',
#  'ASrivastava',
#  'HKuehl',
#  'DMenges',
#  'MOBrien',
#  'FMoss',
#  'JShragge',
#  'DDuncan',
#  'MBerry',
#  'SheyMinSu',
#  'TRosten',
#  'AButtari',
#  'AZiolkowski',
#  'EFranseen',
#  'CAddington',
#  'AWorby',
#  'RobertaHoy',
#  'WBrown',
#  'DonaldHall',
#  'MPelissier',
#  'JLiu',
#  'SRock',
#  'ANadeau',
#  'KSchalkwijk',
#  'JReinhardsen',
#  'BHart',
#  'AParrack',
#  'YNishitsuji',
#  'XueyingLi',
#  'NSparks',
#  'JSamson',
#  'FSantos',
#  'GBlacquiere',
#  'PPodvin',
#  'JPrice',
#  'MMeres',
#  'MRitzwoller',
#  'RFerrari',
#  'WSowerbutts',
#  'IApostoiuMarin',
#  'TheodorKrey',
#  'ThangHa',
#  'JZhu',
#  'MShalley',
#  'CPackard',
#  'PWallis',
#  'RSanderson',
#  'CBurch',
#  'WaiKinChan',
#  'TBowers',
#  'GHursan',
#  'HPerroud',
#  'PeterReid',
#  'RWildman',
#  'TheodoreAsch',
#  'FMorgan',
#  'DChapman',
#  'CWheaton',
#  'EKanasewich',
#  'SMatthies',
#  'RZawislak',
#  'ChoonPark',
#  'RWilliams',
#  'WChadwick',
#  'ATurgut',
#  'RWard',
#  'MLavergne',
#  'WarrenWood',
#  'JDeeks',
#  'HWexler',
#  'JProtazio',
#  'BoZhao',
#  'JorgeLeao',
#  'HAdesokan',
#  'JHe',
#  'AGuarin',
#  'XingjianWang',
#  'JTugnait',
#  'JSharp',
#  'NicaiseYalo',
#  'HandongTan',
#  'RCaldwell',
#  'WilliamKnox',
#  'AJafargandomi',
#  'RRemington',
#  'RFriel',
#  'MCracknell',
#  'ZhilongFang',
#  'TMukerji',
#  'MDablain',
#  'MSmith',
#  'GChavent',
#  'DHamilton',
#  'TimothyCarr',
#  'LAnderson',
#  'JSchuler',
#  'BCacqueray',
#  'MDoyle',
#  'WPreeg',
#  'HWyld',
#  'EHurtig',
#  'CKrawczyk',
#  'JerryWare',
#  'DConnolly',
#  'JohnGoff',
#  'FCastellanos',
#  'HBradner',
#  'CMaurette',
#  'MKatou',
#  'VPasquale',
#  'PSchurholz',
#  'MWidmaier',
#  'MDubesset',
#  'WenjieJiao',
#  'DongJooMin',
#  'CStotter',
#  'GFordham',
#  'KWeitemeyer',
#  'DStewart',
#  'WuzhongLi',
#  'AMcewin',
#  'NCuevas',
#  'ECherkaev',
#  'MKaraoulis',
#  'JProust',
#  'GEdwards',
#  'NanTian',
#  'FengDeng',
#  'YunDai',
#  'WenxiaoQiao',
#  'IDErceville',
#  'JGazdag',
#  'MBrajanovski',
#  'RuiqingHe',
#  'EFregoso',
#  'JThiesson',
#  'RAgersborg',
#  'LDOnofrio',
#  'PSkytta',
#  'JSilic',
#  'WRizer',
#  'MChesley',
#  'RGreen',
#  'KFournier',
#  'JMckelvey',
#  'FSaleck',
#  'BPaulsson',
#  'GDyatlov',
#  'JFriess',
#  'AYoneda',
#  'EHaland',
#  'HMiller',
#  'JamesLong',
#  'JSkelton',
#  'AVincent',
#  'RLacoss',
#  'LAnandababu',
#  'MZuberi',
#  'ZhouYu',
#  'CPretorius',
#  'MDavis',
#  'CMacrides',
#  'WSchmidt',
#  'KarstenBahr',
#  'MSonnenfeld',
#  'AReischer',
#  'MLacasse',
#  'MBruhl',
#  'DTrigg',
#  'DHuang',
#  'RRadtke',
#  'ARucci',
#  'LDolphin',
#  'KeunpilPark',
#  'JKeeney',
#  'AFuqua',
#  'AyonDey',
#  'AMontalvo',
#  'BRafipour',
#  'TGrover',
#  'PLegeido',
#  'DChitu',
#  'JPeirce',
#  'XianhuaiZhu',
#  'RMossman',
#  'MHertrich',
#  'JXiao',
#  ...]

# %%
auth_edges
# Out:
# defaultdict(<function __main__.<lambda>>,
#             {'MKnoll': defaultdict(int,
#                          {'PRouth': 3,
#                           'RKnight': 1,
#                           'TJohnson': 1,
#                           'WBarrash': 5,
#                           'WClement': 4}),
#              'MPrasad': defaultdict(int,
#                          {'MSaidian': 1,
#                           'MZimmer': 2,
#                           'QifeiNiu': 1,
#                           'RMeissner': 1,
#                           'SZargari': 2,
#                           'TWilkinson': 1,
#                           'WWoodruff': 2}),
#              'CReeves': defaultdict(int, {'CTarlowski': 1, 'NPaterson': 1}),
#              'SBiehler': defaultdict(int,
#                          {'StephenPark': 1,
#                           'TienChangLee': 1,
#                           'TiengChangLee': 1,
#                           'WBaldridge': 1,
#                           'WStephenson': 1}),
#              'GSzurek': defaultdict(int,
#                          {'IDuraGomez': 1,
#                           'JStewart': 1,
#                           'KLewallen': 1,
#                           'MDiallo': 1,
#                           'RDuren': 1,
#                           'TommieRape': 1,
#                           'WarrenRoss': 1}),
#              'AKuckes': defaultdict(int,
#                          {'MOristaglio': 1, 'MWorthington': 1}),
#              'BSternberg': defaultdict(int,
#                          {'CGlass': 1,
#                           'JWashburne': 1,
#                           'LPellerin': 1,
#                           'MPoulton': 1}),
#              'JiangLi': defaultdict(int, {'TsiliWang': 1}),
#              'HWang': defaultdict(int,
#                          {'LJones': 1,
#                           'MKing': 1,
#                           'MStauffer': 1,
#                           'NChristensen': 1,
#                           'PWallis': 1,
#                           'ZHajnal': 1}),
#              'KBube': defaultdict(int,
#                          {'PLove': 1,
#                           'RCutler': 1,
#                           'RLangan': 1,
#                           'RShuey': 1,
#                           'TBishop': 1}),
#              'MDehghannejad': defaultdict(int,
#                          {'MSvensson': 1, 'OFriberg': 1, 'PSkytta': 1}),
#              'NYadari': defaultdict(int, {'WMulder': 1}),
#              'JSchleicher': defaultdict(int,
#                          {'LSantos': 3,
#                           'LuizMelo': 1,
#                           'MAlcantara': 1,
#                           'MTygel': 15,
#                           'MakkyJaya': 1,
#                           'PHubral': 15,
#                           'RAleixo': 3,
#                           'RBiloti': 1,
#                           'RPestana': 1,
#                           'TCoimbra': 3,
#                           'THertweck': 1}),
#              'BWitten': defaultdict(int,
#                          {'JShragge': 1, 'MKoerbe': 1, 'PKrajewski': 1}),
#              'MichaelReed': defaultdict(int, {'RChambers': 1}),
#              'WSchneider': defaultdict(int, {'WWhitman': 2}),
#              'PMcgowan': defaultdict(int, {'RSmith': 1}),
#              'RWatts': defaultdict(int, {'WIsherwood': 1, 'WWaller': 1}),
#              'JLea': defaultdict(int, {'RWarren': 1}),
#              'LuanxiaoZhao': defaultdict(int,
#                          {'MinSun': 1,
#                           'QiuliangYao': 3,
#                           'RuiZhou': 1,
#                           'TonglouGuo': 1,
#                           'XuanQin': 2,
#                           'YZhang': 1,
#                           'ZhifangYang': 1}),
#              'JSchmoker': defaultdict(int, {'RCarlson': 1}),
#              'DaleCox': defaultdict(int,
#                          {'GKokkoros': 1,
#                           'HenryTan': 1,
#                           'JBallard': 1,
#                           'JEager': 1,
#                           'JHarris': 1,
#                           'JQueen': 2,
#                           'JSinton': 1,
#                           'JohnBeck': 1,
#                           'LLines': 1,
#                           'MSchaak': 1,
#                           'PBuller': 1,
#                           'PGuerendel': 1,
#                           'RChambers': 1,
#                           'SLazaratos': 1,
#                           'STreitel': 1,
#                           'TDaley': 1,
#                           'WRizer': 1,
#                           'XiangYangLi': 1,
#                           'XinwuZeng': 1}),
#              'GSimmons': defaultdict(int,
#                          {'JRossiter': 1, 'LCaruso': 1, 'RWilkens': 1}),
#              'KennethEuge': defaultdict(int, {'RNorris': 1, 'WMclamore': 1}),
#              'LianghuiGuo': defaultdict(int,
#                          {'RuiGao': 1,
#                           'XiaohongMeng': 1,
#                           'YZheng': 1,
#                           'ZhaoxiChen': 1}),
#              'GAlbis': defaultdict(int,
#                          {'GDeidda': 1, 'GTristano': 1, 'LSambuelli': 1}),
#              'KHambacker': defaultdict(int, {'RBallard': 1, 'RRechtien': 1}),
#              'LKonstantaki': defaultdict(int, {'RGhose': 3, 'THeimovaara': 3}),
#              'JHaldorsen': defaultdict(int,
#                          {'JWalsh': 2,
#                           'KFestervoll': 1,
#                           'MMilenkovic': 1,
#                           'NBrooks': 1,
#                           'PFarmer': 1,
#                           'RCoates': 1,
#                           'SPetersen': 1,
#                           'WLeaney': 1}),
#              'DSmit': defaultdict(int, {'JGeertsma': 1}),
#              'XiaoniuZeng': defaultdict(int, {'XihaiLi': 1}),
#              'IBeresnev': defaultdict(int,
#                          {'PJohnson': 1, 'PVermeer': 1, 'WenDeng': 1}),
#              'DShillington': defaultdict(int, {'JHopper': 1, 'WHolbrook': 1}),
#              'GuangjieWang': defaultdict(int,
#                          {'MiaoyueWang': 1, 'RuoWang': 1}),
#              'IVitorello': defaultdict(int, {'JCosta': 1, 'NTrivedi': 1}),
#              'HWashburn': defaultdict(int, {'HWiley': 1, 'ROlesen': 1}),
#              'MGreenhalgh': defaultdict(int, {'SGreenhalgh': 1, 'TWiese': 1}),
#              'DSunwall': defaultdict(int, {'MSpeece': 1, 'SPekar': 1}),
#              'APoikonen': defaultdict(int, {'ISuppala': 1}),
#              'HFang': defaultdict(int, {'WLai': 1, 'WTsang': 1}),
#              'SGuillon': defaultdict(int, {'YBerthoumieu': 1}),
#              'JJohnson': defaultdict(int,
#                          {'KennethCook': 1,
#                           'RWatson': 1,
#                           'TAnderson': 1,
#                           'VMorse': 1}),
#              'MHatziemmanuel': defaultdict(int, {'RLeyden': 1, 'TCrook': 1}),
#              'AQuarteroni': defaultdict(int,
#                          {'ATaghan': 1, 'EFaccioli': 1, 'FMaggio': 1}),
#              'QingyunDiDi': defaultdict(int, {'ZhiguoAn': 1}),
#              'JKoski': defaultdict(int,
#                          {'LBraile': 1, 'VChandler': 1, 'WHinze': 1}),
#              'JBerryhill': defaultdict(int, {'RGonzalez': 1, 'YKim': 2}),
#              'CPapazachos': defaultdict(int,
#                          {'GTsokas': 3,
#                           'GVargemezis': 1,
#                           'KTzimeas': 1,
#                           'MLoukoyiannakis': 1,
#                           'PSoupios': 1}),
#              'JingtaoZhao': defaultdict(int,
#                          {'SupingPeng': 1, 'WenfengDuDu': 1, 'XiaotingLi': 1}),
#              'NVoogd': defaultdict(int, {'OKoefoed': 1}),
#              'MJones': defaultdict(int,
#                          {'MLayman': 1,
#                           'PKatapodis': 1,
#                           'RFrese': 2,
#                           'RStewart': 1,
#                           'WBeckham': 1,
#                           'WGeis': 1,
#                           'WenLi': 1}),
#              'RThill': defaultdict(int, {'ThomasBur': 1}),
#              'GRice': defaultdict(int, {'PMathieu': 1}),
#              'KFu': defaultdict(int, {'KHuang': 1, 'SCheng': 1, 'ZLin': 1}),
#              'DMagnier': defaultdict(int, {'PeterMora': 1, 'SSophieAdela': 1}),
#              'JPatch': defaultdict(int,
#                          {'JRoberts': 1,
#                           'JWhite': 1,
#                           'OGant': 1,
#                           'RHodgson': 1,
#                           'RobertRice': 1,
#                           'SAllen': 1,
#                           'TLafehr': 1,
#                           'WSchneider': 1}),
#              'HArnetzl': defaultdict(int, {'MKnecht': 1, 'ThKrey': 1}),
#              'CCamerlynck': defaultdict(int,
#                          {'GoncaOkay': 1,
#                           'JCabrera': 1,
#                           'JGirard': 1,
#                           'KChalikakis': 1,
#                           'MDabas': 1,
#                           'MEzersky': 1,
#                           'NFlorsch': 1,
#                           'PCamps': 1,
#                           'PCosenza': 1,
#                           'PLeroy': 1}),
#              'LBorgman': defaultdict(int, {'PShive': 2, 'TLowry': 1}),
#              'PGuerendel': defaultdict(int,
#                          {'RChambers': 1,
#                           'SLazaratos': 1,
#                           'STreitel': 1,
#                           'WRizer': 1}),
#              'JDunbar': defaultdict(int,
#                          {'MMccormack': 1,
#                           'PAllen': 1,
#                           'PHigley': 1,
#                           'SAmidu': 1,
#                           'WSharp': 1}),
#              'GuezGuez': defaultdict(int,
#                          {'HMoralesRodr': 1,
#                           'JCamposEnriquez': 1,
#                           'NNguezMendez': 1}),
#              'AChaturvedi': defaultdict(int,
#                          {'AMaurya': 1,
#                           'CLotter': 1,
#                           'IPatra': 1,
#                           'PParihar': 1,
#                           'STripathi': 1}),
#              'ShengwenJin': defaultdict(int, {'ShiyongXu': 1, 'XiaoBiXie': 1}),
#              'KLau': defaultdict(int,
#                          {'KLouden': 1, 'LWatremez': 1, 'MNedimovic': 1}),
#              'MBuonora': defaultdict(int,
#                          {'MMeju': 1, 'PLugao': 1, 'SFontes': 1}),
#              'HNaudy': defaultdict(int, {'JeromeGery': 1, 'VBaranov': 1}),
#              'BSeymour': defaultdict(int, {'BZelt': 1, 'MYedlin': 1}),
#              'LBerryman': defaultdict(int, {'PGoupillaud': 2}),
#              'AHusseiny': defaultdict(int, {'TVanorio': 2}),
#              'CVuillermoz': defaultdict(int,
#                          {'GCambois': 1, 'SideJin': 1, 'TDavis': 1}),
#              'GZaalbergMetselaar': defaultdict(int,
#                          {'MLandro': 1, 'SVaage': 1}),
#              'YingjieGao': defaultdict(int, {'ZhenxingYao': 1}),
#              'ECaspari': defaultdict(int,
#                          {'JEnnisKing': 1,
#                           'JRubino': 2,
#                           'KHolliger': 2,
#                           'MLebedev': 2,
#                           'MMilani': 1,
#                           'QiaomuQi': 1,
#                           'RPevzner': 2,
#                           'SLopes': 1,
#                           'TDance': 2,
#                           'TMuller': 2,
#                           'YCinar': 2}),
#              'ABeck': defaultdict(int,
#                          {'JConaway': 1,
#                           'PShen': 1,
#                           'RMereu': 1,
#                           'RUffen': 1}),
#              'EmilyFay': defaultdict(int,
#                          {'MNordin': 1, 'RKnight': 3, 'YiQiaoSong': 1}),
#              'MSubrahmanyam': defaultdict(int, {'TRao': 1}),
#              'CanYang': defaultdict(int, {'SFomel': 1, 'SKazemeini': 1}),
#              'JKhazanehdari': defaultdict(int, {'JSothcott': 1}),
#              'HTsu': defaultdict(int,
#                          {'KOgawa': 1, 'RGraf': 1, 'RHansen': 1, 'YOkubo': 1}),
#              'JCarvalho': defaultdict(int, {'JLeote': 1, 'RGhose': 1}),
#              'GNover': defaultdict(int, {'NZisser': 1}),
#              'JohnBeck': defaultdict(int,
#                          {'LLines': 1,
#                           'MSchaak': 1,
#                           'PBuller': 1,
#                           'PGuerendel': 1,
#                           'RChambers': 1,
#                           'SLazaratos': 1,
#                           'STreitel': 1,
#                           'WRizer': 1}),
#              'AndrejBona': defaultdict(int,
#                          {'AndrewKing': 1,
#                           'BGurevich': 2,
#                           'BHansen': 1,
#                           'BaichunSun': 2,
#                           'BinzhongZhou': 2,
#                           'DCooke': 1,
#                           'DNadri': 1,
#                           'KevinUng': 1,
#                           'MAsgharzadeh': 1,
#                           'MBrajanovski': 1,
#                           'MKhoshnavaz': 2,
#                           'MLebedev': 1,
#                           'MSlawinski': 1,
#                           'MUrosevic': 3,
#                           'MWerken': 1,
#                           'PSmith': 1,
#                           'RPevzner': 2,
#                           'TLokajicek': 1}),
#              'ZhanxiangHe': defaultdict(int, {'ZuzhiHu': 2}),
#              'GGaynor': defaultdict(int, {'GMcmechan': 1, 'RSzerbiak': 1}),
#              'BRussell': defaultdict(int,
#                          {'DHampson': 1,
#                           'DavidGray': 1,
#                           'FHilterman': 1,
#                           'KHedlin': 1,
#                           'LLines': 1}),
#              'DKumar': defaultdict(int, {'MrinalSen': 1, 'RFerguson': 1}),
#              'HEmmerich': defaultdict(int, {'MichaelKorn': 1}),
#              'OPedersen': defaultdict(int, {'SBrandsbergDahl': 1}),
#              'GVoorhis': defaultdict(int,
#                          {'MRichards': 1,
#                           'PKintzinger': 1,
#                           'PNelson': 3,
#                           'StanleyWard': 1,
#                           'TDrake': 1,
#                           'VVacquier': 1}),
#              'AKuvshinov': defaultdict(int,
#                          {'DAvdeev': 1,
#                           'GNewman': 1,
#                           'JHubert': 1,
#                           'LPedersen': 1,
#                           'OPankratov': 1,
#                           'TKalscheuer': 1,
#                           'TLochbuhler': 1}),
#              'JTrier': defaultdict(int, {'WSymes': 1}),
#              'MBeiki': defaultdict(int, {'MPilkington': 1}),
#              'DKouri': defaultdict(int,
#                          {'FHussain': 1,
#                           'FuchunGao': 1,
#                           'JieYao': 1,
#                           'KaushikMaji': 1,
#                           'SAbeykoon': 1}),
#              'HZhang': defaultdict(int,
#                          {'HongLiu': 1,
#                           'JZhang': 2,
#                           'JinYang': 1,
#                           'JinchengXu': 1,
#                           'JinglingXu': 1,
#                           'JoseLira': 1,
#                           'JuFeng': 1,
#                           'JunlunLi': 1,
#                           'KInnanen': 1,
#                           'LuLiu': 1,
#                           'MToksoz': 3,
#                           'MengLi': 1,
#                           'MingLiu': 1,
#                           'MinzhuLiu': 1,
#                           'SSarkar': 1,
#                           'SShaw': 1,
#                           'TianyiWang': 1,
#                           'XiangHu': 1,
#                           'XiangdeTang': 1,
#                           'XiangyunHu': 1,
#                           'YMarangoni': 1,
#                           'YZhang': 1,
#                           'YuxingQin': 1,
#                           'ZhenLiu': 1,
#                           'ZhiyangWang': 1}),
#              'GGribler': defaultdict(int,
#                          {'LLiberty': 1, 'PMichaels': 1, 'TMikesell': 1}),
#              'HauWeiZhou': defaultdict(int,
#                          {'JMcdonald': 1, 'RSheriff': 1, 'StephenHa': 1}),
#              'RSteinhoff': defaultdict(int, {'WRussell': 1}),
#              'PeimingLi': defaultdict(int,
#                          {'WengeLiu': 1, 'ZhihuiYan': 1, 'ZhihuiZou': 1}),
#              'KDieter': defaultdict(int, {'NPaterson': 1}),
#              'CVuik': defaultdict(int,
#                          {'HKnibbe': 1,
#                           'RPlessix': 1,
#                           'WMulder': 2,
#                           'YErlangga': 1}),
#              'DRhodes': defaultdict(int, {'WMott': 1}),
#              'JDufour': defaultdict(int, {'JSquires': 1, 'WGoodway': 1}),
#              'LPorter': defaultdict(int, {'RFredricks': 1}),
#              'ABaird': defaultdict(int, {'DAngus': 1, 'JKendall': 1}),
#              'NRykhlinski': defaultdict(int,
#                          {'PLegeido': 1, 'SDavydycheva': 2}),
#              'JFolesky': defaultdict(int, {'JKummerow': 1, 'SShapiro': 1}),
#              'HugoPena': defaultdict(int, {'RPlaisted': 1}),
#              'AGregory': defaultdict(int,
#                          {'APodio': 1,
#                           'ATutuncu': 1,
#                           'GGardner': 4,
#                           'LGardner': 2,
#                           'LMorley': 1,
#                           'MBower': 1,
#                           'MSharma': 1,
#                           'MWyllie': 4}),
#              'BGelchinsky': defaultdict(int, {'ELanda': 1, 'VShtivelman': 1}),
#              'DavidHart': defaultdict(int, {'HerbertWang': 1}),
#              'UMeyer': defaultdict(int, {'WolfgangVoss': 1}),
#              'RCatchings': defaultdict(int, {'WLutter': 2}),
#              'EStatham': defaultdict(int, {'JMartinez': 2, 'LHowell': 2}),
#              'LMorrison': defaultdict(int, {'RWatson': 1}),
#              'JungkyunShin': defaultdict(int, {'YoungseoKim': 1}),
#              'EOblow': defaultdict(int, {'JBarhen': 1, 'JDubose': 1}),
#              'JLymburner': defaultdict(int, {'RSmith': 1}),
#              'CHouser': defaultdict(int,
#                          {'MEverett': 1, 'PBarrineau': 1, 'PWernette': 1}),
#              'BinLiu': defaultdict(int, {'MSacchi': 1}),
#              'JGrant': defaultdict(int, {'RGrasty': 1}),
#              'RGhose': defaultdict(int,
#                          {'SMinato': 2,
#                           'THeimovaara': 3,
#                           'TTakahashi': 1,
#                           'VNijhof': 1,
#                           'WVersteeg': 1,
#                           'YKaida': 1,
#                           'YMatsubara': 1}),
#              'BjarneNost': defaultdict(int, {'EHaslund': 1}),
#              'AKenyon': defaultdict(int, {'CBeckett': 1, 'DMorrice': 1}),
#              'BinghengYuan': defaultdict(int,
#                          {'GuizhongWang': 1,
#                           'HongliuZeng': 1,
#                           'LiguiXu': 1,
#                           'RLoucks': 1,
#                           'XJanson': 1,
#                           'YipingXia': 1}),
#              'JoostNeut': defaultdict(int,
#                          {'KMehta': 1,
#                           'KWapenaar': 5,
#                           'NAllouche': 1,
#                           'RSnieder': 1,
#                           'SSingh': 1}),
#              'DenisGill': defaultdict(int, {'LGeldart': 1}),
#              'SSavazzi': defaultdict(int, {'USpagnolini': 1}),
#              'JianjunZeng': defaultdict(int, {'JintanLi': 1, 'PoGeng': 1}),
#              'SCheng': defaultdict(int, {'ZLin': 1}),
#              'ALegchenko': defaultdict(int,
#                          {'CCamerlynck': 1,
#                           'CChampollion': 1,
#                           'CVincent': 1,
#                           'ChristianAlle': 1,
#                           'EThibert': 1,
#                           'FLawson': 1,
#                           'HJourde': 1,
#                           'JGirard': 1,
#                           'JVouillamoz': 2,
#                           'JeanRoy': 1,
#                           'KChalikakis': 2,
#                           'MBoucher': 2,
#                           'MDescloitres': 1,
#                           'MEzersky': 1,
#                           'NMazzilli': 1,
#                           'SGarambois': 1}),
#              'HKaraoglu': defaultdict(int, {'JBielak': 1, 'RTaborda': 1}),
#              'EThibert': defaultdict(int, {'SGarambois': 1}),
#              'GHenry': defaultdict(int, {'RCarmichael': 1}),
#              'ABobet': defaultdict(int, {'LPyrakNolte': 1, 'MinKwangChoi': 1}),
#              'SChung': defaultdict(int, {'SungryulShin': 1}),
#              'DEpili': defaultdict(int,
#                          {'FAudebert': 1,
#                           'GMcmechan': 2,
#                           'HChang': 1,
#                           'JVandyke': 1,
#                           'JunCai': 1,
#                           'MSolano': 1,
#                           'ManhongGuo': 1,
#                           'PGuillaume': 1,
#                           'SGajawada': 1,
#                           'VDirks': 1}),
#              'HaoGuo': defaultdict(int,
#                          {'JianleiLiu': 1, 'KMarfurt': 2, 'SLewis': 1}),
#              'SBrowning': defaultdict(int, {'StephaniePark': 1}),
#              'JGillin': defaultdict(int, {'LShock': 1}),
#              'JPoole': defaultdict(int, {'RBroding': 1}),
#              'EdwardSalo': defaultdict(int, {'GSchuster': 1}),
#              'EWinniski': defaultdict(int, {'PHallof': 1}),
#              'MJeannin': defaultdict(int, {'SGarambois': 1}),
#              'SGelinsky': defaultdict(int, {'SShapiro': 1}),
#              'HEicken': defaultdict(int, {'HMiller': 1, 'SGerland': 1}),
#              'MQueisser': defaultdict(int, {'SSingh': 1}),
#              'MRivest': defaultdict(int, {'PShamsipour': 1}),
#              'SPeacock': defaultdict(int, {'TAstin': 1}),
#              'ABaggeroer': defaultdict(int, {'KaiHsu': 1}),
#              'EPracser': defaultdict(int,
#                          {'FBosch': 1,
#                           'IMuller': 1,
#                           'LSzarka': 1,
#                           'PTurberg': 1,
#                           'SSzalai': 1}),
#              'HWhite': defaultdict(int, {'WFarren': 1}),
#              'CMiller': defaultdict(int,
#                          {'JMcnamara': 1, 'PRouth': 1, 'TBrosten': 1}),
#              'PTesch': defaultdict(int, {'SWessling': 1}),
#              'AForster': defaultdict(int,
#                          {'BNorden': 1,
#                           'CCosma': 1,
#                           'CJuhlin': 1,
#                           'DBlackwell': 1,
#                           'DMerriam': 1,
#                           'HKazemeini': 1,
#                           'JSchrotter': 1,
#                           'KZinckJorgensen': 1,
#                           'NJuhojuntti': 1,
#                           'RGiese': 1,
#                           'StefanLuth': 1}),
#              'MadelineLee': defaultdict(int, {'WMorris': 1}),
#              'NSaito': defaultdict(int, {'RCoifman': 1}),
#              'AFraser': defaultdict(int, {'ATurpie': 1, 'FMoss': 1}),
#              'HuiyiLu': defaultdict(int,
#                          {'XuejianLiu': 1, 'YZheng': 1, 'YikeLiu': 1}),
#              'GPapanicolaou': defaultdict(int, {'LBorcea': 1}),
#              'ELanda': defaultdict(int,
#                          {'GRoeth': 1,
#                           'IBelfer': 2,
#                           'IBruner': 1,
#                           'MJannane': 1,
#                           'MMendes': 1,
#                           'MNoble': 1,
#                           'MReshef': 1,
#                           'MTaner': 1,
#                           'MXie': 1,
#                           'PThore': 1,
#                           'RBaina': 1,
#                           'RSnieder': 1,
#                           'SFomel': 1,
#                           'SKeydar': 4,
#                           'SSingh': 1,
#                           'ShaharArad': 1,
#                           'TMoser': 1,
#                           'VKhaidukov': 1,
#                           'VShtivelman': 1,
#                           'VSorin': 1,
#                           'WBeydoun': 2,
#                           'YHassin': 1,
#                           'ZKoren': 3}),
#              'LucianBalu': defaultdict(int, {'NEnescu': 1}),
#              'EPervago': defaultdict(int, {'MMarkov': 1}),
#              'FHilterman': defaultdict(int,
#                          {'GGoloshubin': 2,
#                           'HaitaoRen': 2,
#                           'ITsvankin': 1,
#                           'KHedlin': 1,
#                           'LLines': 1,
#                           'RichardVerm': 1,
#                           'TDavis': 1,
#                           'ZhengyunZhou': 1}),
#              'PBerg': defaultdict(int, {'RBorselen': 1}),
#              'GHocht': defaultdict(int,
#                          {'JCruz': 1,
#                           'JSchleicher': 2,
#                           'JurgenMann': 1,
#                           'MTygel': 1,
#                           'PHubral': 3,
#                           'RJager': 1}),
#              'EBaysal': defaultdict(int,
#                          {'JSherwood': 1, 'LeeLu': 1, 'MTaner': 1}),
#              'IMorozov': defaultdict(int,
#                          {'JinfengMa': 1, 'SSmithson': 2, 'WubingDeng': 3}),
#              'CHyslop': defaultdict(int, {'RStewart': 1}),
#              'SeungGooKang': defaultdict(int, {'WansooHa': 1}),
#              'DBarnes': defaultdict(int,
#                          {'MUnsworth': 1, 'VTuncer': 1, 'WSoyer': 1}),
#              'ABrown': defaultdict(int,
#                          {'AGerhardstein': 1,
#                           'CSelman': 1,
#                           'EMccollum': 1,
#                           'GEdwards': 1,
#                           'JCarlisle': 1,
#                           'KBurkart': 1,
#                           'RGalbraith': 1,
#                           'RHoward': 1,
#                           'RSpecht': 1,
#                           'RWright': 1,
#                           'TLautzenhiser': 1,
#                           'WAbriel': 1}),
#              'FSciraScappuzzo': defaultdict(int,
#                          {'JSogade': 1,
#                           'WeiqunShi': 1,
#                           'WilliamRodi': 1,
#                           'YVichabian': 1}),
#              'FAndreasi': defaultdict(int,
#                          {'FSnyder': 1,
#                           'MStefano': 1,
#                           'MVirgilio': 1,
#                           'SimoneRe': 1}),
#              'JWashburne': defaultdict(int, {'LPellerin': 1}),
#              'GCheng': defaultdict(int, {'ShimonCoen': 1}),
#              'RamaRao': defaultdict(int, {'ZhenyaZhu': 1}),
#              'PHuddleston': defaultdict(int, {'RStewart': 1, 'TzeKan': 1}),
#              'KBurkart': defaultdict(int, {'RWright': 1, 'WAbriel': 1}),
#              'DaniOr': defaultdict(int, {'RFriel': 1}),
#              'MSkold': defaultdict(int,
#                          {'SHubbard': 2, 'TMehlhorn': 1, 'YuxinWu': 1}),
#              'GCampbell': defaultdict(int, {'MUrosevic': 1, 'RDurrheim': 1}),
#              'CKean': defaultdict(int, {'LHowell': 2, 'RThompson': 1}),
#              'RHassan': defaultdict(int, {'TimothyDean': 1}),
#              'HPickett': defaultdict(int, {'LTornheim': 1}),
#              'HTewari': defaultdict(int,
#                          {'KKaila': 2, 'MDixit': 1, 'VKrishna': 1}),
#              'PRomig': defaultdict(int, {'TDobecki': 1}),
#              'APrice': defaultdict(int,
#                          {'FJones': 1,
#                           'GPajot': 1,
#                           'MDiament': 1,
#                           'VMikhailov': 1}),
#              'RBeach': defaultdict(int, {'RCooper': 1}),
#              'BSmithyman': defaultdict(int,
#                          {'JHayles': 1,
#                           'RClowes': 1,
#                           'RPratt': 1,
#                           'RWittebolle': 1}),
#              'JCoon': defaultdict(int, {'JFowler': 1}),
#              'RMadariaga': defaultdict(int, {'SideJin': 2, 'TGeorge': 1}),
#              'YongMa': defaultdict(int, {'ZhaoboMeng': 1}),
#              'JXiang': defaultdict(int, {'NJones': 1}),
#              'IMuller': defaultdict(int,
#                          {'LSzarka': 1, 'PTurberg': 1, 'SSzalai': 1}),
#              'ALundsgaard': defaultdict(int, {'HKlemm': 1}),
#              'ARatcliffe': defaultdict(int,
#                          {'AUmpleby': 1,
#                           'CarolineWin': 1,
#                           'GConroy': 2,
#                           'GRoberts': 1,
#                           'IStekl': 1,
#                           'JMorgan': 1,
#                           'LGuasch': 1,
#                           'LianDuan': 1,
#                           'MWarner': 1,
#                           'NSilva': 1,
#                           'NikhilShah': 1,
#                           'TNangoo': 1,
#                           'VVinje': 2,
#                           'YZhang': 1}),
#              'HKazemeini': defaultdict(int,
#                          {'KZinckJorgensen': 1,
#                           'NJuhojuntti': 1,
#                           'RGiese': 1,
#                           'StefanLuth': 1}),
#              'EGraeva': defaultdict(int,
#                          {'MDiament': 1,
#                           'PSailhac': 1,
#                           'SAgayan': 1,
#                           'SBogoutdinov': 1,
#                           'VMikhailov': 1}),
#              'MarcAndreChen': defaultdict(int, {'RHyndman': 1, 'SDosso': 1}),
#              'AClark': defaultdict(int,
#                          {'DSalt': 1,
#                           'HansRudolfWenk': 1,
#                           'TVanorio': 1,
#                           'WKanitpanyacharoen': 1}),
#              'KSegeth': defaultdict(int, {'VBezvoda': 2}),
#              'BSiemon': defaultdict(int,
#                          {'ETordiffe': 1,
#                           'HWiederhold': 1,
#                           'JElbracht': 1,
#                           'KSengpiel': 2,
#                           'NicoDeus': 1,
#                           'SCostabel': 1,
#                           'StefanMaus': 1,
#                           'TGunther': 1,
#                           'UMeyer': 1,
#                           'WolfgangVoss': 1}),
#              'LNicoletis': defaultdict(int,
#                          {'MKern': 1,
#                           'PJoly': 1,
#                           'RTurpening': 1,
#                           'VAnsel': 1,
#                           'VFarra': 1}),
#              'MCampillo': defaultdict(int,
#                          {'MCorciulo': 2,
#                           'MTanter': 1,
#                           'NShapiro': 1,
#                           'PGouedard': 3,
#                           'PhilippeRoux': 8,
#                           'PierreBoue': 1,
#                           'RHilst': 1,
#                           'RLynch': 1,
#                           'RWeaver': 1,
#                           'SCatheline': 1,
#                           'SGaffet': 1,
#                           'SHusen': 1,
#                           'TPlanes': 1,
#                           'WKuperman': 1}),
#              'IKoulakov': defaultdict(int, {'TStupina': 1}),
#              'GWilson': defaultdict(int,
#                          {'LeWan': 1,
#                           'LeifCox': 1,
#                           'MZhdanov': 2,
#                           'XiaojunLiu': 1}),
#              'DBhattacharjya': defaultdict(int,
#                          {'JEidsvik': 1, 'TMukerji': 1}),
#              'LGochioco': defaultdict(int, {'SCotten': 1}),
#              'GDiaferia': defaultdict(int,
#                          {'LKonstantaki': 1, 'RGhose': 1, 'THeimovaara': 1}),
#              'RadimCiz': defaultdict(int, {'SSchmalholz': 1, 'SShapiro': 3}),
#              'DBlankenship': defaultdict(int,
#                          {'DSchroeder': 1,
#                           'GTsoflias': 1,
#                           'JGestel': 1,
#                           'LopamudraRoy': 1,
#                           'MrinalSen': 2,
#                           'PStoffa': 2,
#                           'TRichter': 1}),
#              'GStuart': defaultdict(int, {'WeijianMao': 2}),
#              'JKouba': defaultdict(int, {'RBeach': 1}),
#              'CBeckett': defaultdict(int, {'DMorrice': 1}),
#              'TingEnFan': defaultdict(int, {'XiaolanLei': 1, 'ZhiguoWang': 1}),
#              'PWessel': defaultdict(int, {'WSmith': 1}),
#              'AZemanian': defaultdict(int, {'BAnderson': 1}),
#              'MMushayandebvu': defaultdict(int,
#                          {'MOdegard': 1, 'PDriel': 1, 'VLesur': 1}),
#              'KLange': defaultdict(int,
#                          {'KMosegaard': 1, 'THansen': 1, 'YMelnikova': 1}),
#              'KHayley': defaultdict(int, {'LBentley': 1}),
#              'GAsquith': defaultdict(int, {'RMajor': 1, 'VPendleton': 1}),
#              'EAnderson': defaultdict(int,
#                          {'JamesLang': 2,
#                           'KKelley': 2,
#                           'MHitzman': 1,
#                           'PBedrosian': 1,
#                           'TMonecke': 1,
#                           'WeiZhou': 1,
#                           'YaoguoLi': 1}),
#              'HRomero': defaultdict(int, {'LDOnofrio': 1}),
#              'SNicoletis': defaultdict(int, {'SSpitz': 1, 'YGoldman': 1}),
#              'ShuqianDong': defaultdict(int,
#                          {'XiangXiao': 1,
#                           'YanweiXue': 1,
#                           'YiLuo': 2,
#                           'YiboWang': 1}),
#              'JFinol': defaultdict(int, {'XuDongJing': 1}),
#              'JKellogg': defaultdict(int,
#                          {'JUrrutiaFucugauchi': 1,
#                           'MPilkington': 1,
#                           'MVeronneau': 1,
#                           'MWebring': 1,
#                           'RForsberg': 1,
#                           'RKucks': 1,
#                           'RMorin': 1,
#                           'THildenbrand': 1,
#                           'WHinze': 1,
#                           'XiongLi': 1}),
#              'ShuoJi': defaultdict(int, {'THuang': 1, 'ZhengxueLi': 1}),
#              'MTempleton': defaultdict(int,
#                          {'RWilliams': 1, 'TPratt': 1, 'WStephenson': 1}),
#              'HuJin': defaultdict(int, {'HuiminGuan': 1}),
#              'LMartino': defaultdict(int, {'NBonomo': 1, 'NRatto': 1}),
#              'XuJi': defaultdict(int, {'YiLuo': 1}),
#              'GuentherNeto': defaultdict(int,
#                          {'LAzevedo': 2,
#                           'LGuerreiro': 1,
#                           'PCorreia': 1,
#                           'RNunes': 2}),
#              'APerelberg': defaultdict(int, {'SHornbostel': 1}),
#              'NCanitez': defaultdict(int, {'RSaatcilar': 3, 'SErgintav': 1}),
#              'HAshraf': defaultdict(int, {'SDossary': 1, 'WMousa': 1}),
#              'JiaqiYang': defaultdict(int, {'THabashy': 2}),
#              'DMarchant': defaultdict(int, {'DOldenburg': 1, 'EHaber': 1}),
#              'NGodfrey': defaultdict(int, {'TMukerji': 1}),
#              'GGulmon': defaultdict(int, {'NSmith': 1}),
#              'AAhmadifard': defaultdict(int,
#                          {'AKahoo': 1,
#                           'HMarvi': 1,
#                           'MSiahsar': 1,
#                           'SGholtashi': 1}),
#              'CGehin': defaultdict(int, {'PBlavier': 1}),
#              'MatthewJosh': defaultdict(int, {'TongchengHan': 1}),
#              'BRao': defaultdict(int,
#                          {'CRao': 1, 'IMurthy': 1, 'MSastri': 1, 'TRao': 1}),
#              'AMordret': defaultdict(int,
#                          {'NShapiro': 1,
#                           'OBarkved': 1,
#                           'PhilippeRoux': 1,
#                           'SSingh': 1}),
#              'JLyons': defaultdict(int, {'JMair': 1}),
#              'ADeighan': defaultdict(int, {'DWatts': 1}),
#              'KwangjinYoon': defaultdict(int,
#                          {'KwonPark': 1,
#                           'ManhongGuo': 1,
#                           'SChung': 1,
#                           'SeungwonKo': 3,
#                           'SoondukHong': 2,
#                           'SungryulShin': 2,
#                           'TaeyoungHa': 2,
#                           'WonsikKim': 2,
#                           'YounghoCha': 1,
#                           'ZhimingLi': 1}),
#              'EFlekkoy': defaultdict(int,
#                          {'EHaland': 2,
#                           'KMaloy': 2,
#                           'OAursjo': 1,
#                           'SPride': 1}),
#              'DeshuXu': defaultdict(int, {'HandongTan': 1, 'HualinZeng': 1}),
#              'FSmolka': defaultdict(int, {'LGriffiths': 1, 'LTrembly': 1}),
#              'ChenLi': defaultdict(int, {'DPatterson': 1, 'XiaoMingTang': 1}),
#              'DRevelo': defaultdict(int, {'RPestana': 1}),
#              'JeongminYu': defaultdict(int,
#                          {'JoongmooByun': 1, 'SoonSeol': 1}),
#              'ACrosta': defaultdict(int,
#                          {'APires': 1,
#                           'ASilva': 2,
#                           'CBarros': 1,
#                           'CCarneiro': 1,
#                           'JCurto': 1,
#                           'SFraser': 1}),
#              'EGonzalo': defaultdict(int, {'JMartinez': 1, 'TMukerji': 1}),
#              'ADuijndam': defaultdict(int,
#                          {'CHindriks': 1,
#                           'GHaugen': 1,
#                           'HCruts': 1,
#                           'JFokkema': 1,
#                           'JGroenenboom': 1,
#                           'KHindriks': 1,
#                           'LOngkiehong': 1,
#                           'MDillen': 1,
#                           'MSchonewille': 5,
#                           'OEiken': 1,
#                           'RRomijn': 1}),
#              'MProvart': defaultdict(int, {'SMiller': 1, 'WHolbrook': 1}),
#              'DPhillips': defaultdict(int,
#                          {'HeloiseLynn': 1,
#                           'KSimon': 1,
#                           'RGrimm': 1,
#                           'WBeckham': 1}),
#              'VVavrycuk': defaultdict(int, {'ZhaoLi': 1}),
#              'VLabson': defaultdict(int, {'WAnderson': 1}),
#              'SGupta': defaultdict(int,
#                          {'SMisra': 1, 'SSharma': 1, 'WMohanty': 1}),
#              'GPerez': defaultdict(int, {'KLarner': 1, 'KMarfurt': 3}),
#              'JSkinner': defaultdict(int, {'MDabas': 1}),
#              'EGaucher': defaultdict(int, {'MStAmant': 1}),
#              'FSantos': defaultdict(int,
#                          {'HElKaliouby': 1,
#                           'JTriantafilis': 2,
#                           'KBruzgulis': 1,
#                           'RWege': 1,
#                           'VWong': 1}),
#              'HJaramillo': defaultdict(int, {'JCohen': 1, 'NBleistein': 2}),
#              'MikeBerg': defaultdict(int, {'SSomerstein': 1, 'WSalisbury': 1}),
#              'LAllen': defaultdict(int, {'RCaldwell': 2, 'WMills': 2}),
#              'LingshunMeng': defaultdict(int, {'ZhenJia': 1}),
#              'ILindell': defaultdict(int, {'KNikoskinen': 2, 'MErmutlu': 2}),
#              'EForte': defaultdict(int, {'MDossi': 2, 'MPipan': 2}),
#              'BHoffe': defaultdict(int,
#                          {'DFoltinek': 1,
#                           'GMargrave': 1,
#                           'HBland': 1,
#                           'JGulati': 1,
#                           'PManning': 1,
#                           'RStewart': 2}),
#              'HuiWang': defaultdict(int,
#                          {'JingChen': 1,
#                           'MCates': 1,
#                           'XChang': 1,
#                           'YikeLiu': 1,
#                           'ZhijingWang': 1}),
#              'MGregotski': defaultdict(int, {'OJensen': 1}),
#              'QianZhao': defaultdict(int, {'XJiang': 1, 'ZongbenXu': 1}),
#              'JamesLee': defaultdict(int,
#                          {'KLeslie': 1,
#                           'LBeard': 2,
#                           'MDowney': 1,
#                           'RBinks': 1,
#                           'RLahti': 1,
#                           'RTurner': 1,
#                           'TGamey': 2,
#                           'WMurray': 1,
#                           'WilliamDoll': 2}),
#              'CBates': defaultdict(int,
#                          {'DPhillips': 1,
#                           'HeloiseLynn': 2,
#                           'KSimon': 2,
#                           'MJones': 1,
#                           'MLayman': 1,
#                           'RGrimm': 1,
#                           'WBeckham': 2}),
#              'JSheehan': defaultdict(int,
#                          {'JamesLee': 1,
#                           'LBeard': 1,
#                           'RLahti': 1,
#                           'TGamey': 1,
#                           'WilliamDoll': 1}),
#              'EHerrin': defaultdict(int, {'SClark': 1}),
#              'PPodvin': defaultdict(int,
#                          {'PThierry': 3, 'SBegat': 1, 'SOperto': 2}),
#              'FRenalier': defaultdict(int,
#                          {'GGiulio': 1,
#                           'MOhrnberger': 1,
#                           'MWathelet': 2,
#                           'NTheodoulidis': 1,
#                           'PierreYvesBard': 1}),
#              'AFerretti': defaultdict(int, {'DVasco': 3, 'FNovali': 2}),
#              'ZGuanQuan': defaultdict(int, {'ZShuLun': 1}),
#              'HCruts': defaultdict(int,
#                          {'JFokkema': 1, 'JGroenenboom': 1, 'MDillen': 1}),
#              'JKapoor': defaultdict(int, {'NMoldoveanu': 1}),
#              'KNakayama': defaultdict(int,
#                          {'MTakanashi': 1, 'MuLuo': 1, 'TEzaka': 1}),
#              'DavidPai': defaultdict(int,
#                          {'JAhmad': 1, 'MHuang': 1, 'WKennedy': 1}),
#              'JSinton': defaultdict(int,
#                          {'JWatkins': 1,
#                           'JohnBeck': 1,
#                           'LLines': 1,
#                           'MSchaak': 1,
#                           'PBuller': 1,
#                           'PGuerendel': 1,
#                           'RChambers': 1,
#                           'RWard': 1,
#                           'SLazaratos': 1,
#                           'STreitel': 1,
#                           'WRizer': 1}),
#              'IPanea': defaultdict(int, {'VMocanu': 1}),
#              'MMeres': defaultdict(int, {'MMuskat': 2}),
#              'ABenMenahem': defaultdict(int, {'SKostek': 1}),
#              'JCarter': defaultdict(int, {'LFrazer': 1}),
#              'HHelle': defaultdict(int,
#                          {'JCarcione': 7,
#                           'JPajchel': 1,
#                           'JSantos': 1,
#                           'KKlemMusatov': 1,
#                           'MAyzenberg': 1,
#                           'NamPham': 2,
#                           'PAvseth': 1,
#                           'TToverud': 1,
#                           'TongZhao': 1}),
#              'EwoutBerg': defaultdict(int,
#                          {'FHerrmann': 1,
#                           'GHennenfent': 1,
#                           'MFriedlander': 1}),
#              'MWoodward': defaultdict(int, {'OZdraveva': 2}),
#              'OAgudo': defaultdict(int, {'PCaprioli': 1}),
#              'NiuWei': defaultdict(int, {'WWensheng': 1}),
#              'COfficer': defaultdict(int, {'WBeckmann': 1, 'WMcguinness': 1}),
#              'BJafarpour': defaultdict(int,
#                          {'DMclaughlin': 1, 'VGoyal': 1, 'WFreeman': 1}),
#              'AGallois': defaultdict(int,
#                          {'FFournier': 1,
#                           'JBorgomano': 1,
#                           'KBiscarrat': 1,
#                           'PLeonide': 1}),
#              'BMcadoo': defaultdict(int,
#                          {'EMorgan': 1,
#                           'ILecomte': 1,
#                           'LBaise': 1,
#                           'MVanneste': 1,
#                           'OLongva': 1}),
#              'LAmundsen': defaultdict(int,
#                          {'LIkelle': 3,
#                           'LLoseth': 3,
#                           'LarsBerg': 1,
#                           'MLandro': 6,
#                           'MThompson': 1,
#                           'MVasmel': 1,
#                           'RMittet': 2,
#                           'RSollie': 1,
#                           'SEllingsrud': 2,
#                           'SWyatt': 1,
#                           'SeungYoo': 1,
#                           'TRosten': 1,
#                           'YuanNi': 1}),
#              'DHannay': defaultdict(int,
#                          {'GSpence': 1,
#                           'JGettrust': 1,
#                           'NChapman': 1,
#                           'RHyndman': 1,
#                           'RWalia': 1,
#                           'WarrenWood': 1}),
#              'MVoltolini': defaultdict(int, {'NMondol': 1}),
#              'ShenWang': defaultdict(int, {'XiaoyeLi': 1}),
#              'ASauter': defaultdict(int, {'LDorman': 1}),
#              'AnningHou': defaultdict(int, {'KMarfurt': 1}),
#              'JSimmons': defaultdict(int,
#                          {'KOliver': 1,
#                           'MBackus': 4,
#                           'REdson': 1,
#                           'RElphick': 2,
#                           'RJohns': 2,
#                           'RLevey': 1,
#                           'VPendleton': 4}),
#              'PHarben': defaultdict(int, {'SJarpe': 1}),
#              'RPlessix': defaultdict(int,
#                          {'SaidAbri': 1,
#                           'TAlkhalifah': 1,
#                           'WMulder': 3,
#                           'YErlangga': 1}),
#              'PMatuszyk': defaultdict(int, {'SHuang': 1, 'WeiLi': 1}),
#              'AAsnaashari': defaultdict(int,
#                          {'AStovas': 1,
#                           'BDupuy': 1,
#                           'FAudebert': 1,
#                           'HBalhareth': 1,
#                           'JVirieux': 2,
#                           'MLandro': 1,
#                           'PThore': 1,
#                           'RBrossier': 1,
#                           'SGarambois': 2}),
#              'JSallas': defaultdict(int, {'RBrook': 1, 'RLandrum': 1}),
#              'MDabas': defaultdict(int, {'PCamps': 1}),
#              'GregoryEly': defaultdict(int,
#                          {'MKilmer': 1, 'NingHao': 1, 'SAeron': 1}),
#              'RLopes': defaultdict(int, {'TBarros': 1}),
#              'VDruskin': defaultdict(int, {'VSimoncini': 1}),
#              'ATakahata': defaultdict(int,
#                          {'DSerrano': 1,
#                           'EAsgedom': 1,
#                           'JRomano': 1,
#                           'KNoseFilho': 1,
#                           'LGelius': 1,
#                           'MTygel': 1,
#                           'RLopes': 1}),
#              'YangyangYu': defaultdict(int, {'YihaiYang': 1}),
#              'DaxingWang': defaultdict(int,
#                          {'JinghuaiGao': 2,
#                           'QianshengWei': 1,
#                           'XiaojieCui': 1,
#                           'XiaolanLei': 1,
#                           'ZhiguoWang': 2}),
#              'DNichols': defaultdict(int,
#                          {'FAudebert': 1,
#                           'FrancisMuir': 1,
#                           'HUrdaneta': 1,
#                           'JDellinger': 1,
#                           'JEtgen': 1,
#                           'KOsypov': 2,
#                           'MWoodward': 2,
#                           'OZdraveva': 2,
#                           'RClapp': 3,
#                           'TRekdal': 1,
#                           'YunyueLi': 3}),
#              'SPehrsson': defaultdict(int, {'VTschirhart': 1}),
#              'JOsoba': defaultdict(int, {'KRibe': 1}),
#              'LeeHunt': defaultdict(int,
#                          {'MHadley': 1, 'SHadley': 1, 'SReynolds': 1}),
#              'ABasokur': defaultdict(int,
# ...
#              'BRummerfield': defaultdict(int,
#                          {'DHoover': 1, 'NMorrisey': 1, 'RBroding': 1}),
#              'HaiLou': defaultdict(int,
#                          {'HualinZeng': 1,
#                           'XiaohongMeng': 1,
#                           'XiaomengLi': 1,
#                           'ZGuang': 1,
#                           'ZhipingLi': 1}),
#              'AOgilvy': defaultdict(int, {'EKuzmina': 1, 'VBogoslovsky': 1}),
#              'FHron': defaultdict(int, {'JCovey': 1, 'PDaley': 2}),
#              'WenjieJiao': defaultdict(int, {'YuXia': 1}),
#              'DPitcher': defaultdict(int, {'GLinford': 2, 'HSeigel': 3}),
#              'ILerche': defaultdict(int,
#                          {'JOBrien': 1,
#                           'JResnick': 1,
#                           'NBanik': 1,
#                           'NHill': 1,
#                           'RCutler': 1,
#                           'RLangan': 1,
#                           'RShuey': 1,
#                           'SCao': 2,
#                           'SongCao': 2}),
#              'GBishop': defaultdict(int, {'SHornbostel': 1}),
#              'MPurucker': defaultdict(int, {'TSabaka': 1}),
#              'HeeKim': defaultdict(int,
#                          {'JungSuh': 2,
#                           'KiLee': 5,
#                           'SoonSeol': 1,
#                           'TaeLee': 1,
#                           'YoonhoSong': 4}),
#              'BSingh': defaultdict(int, {'DGuptasarma': 2}),
#              'EStolz': defaultdict(int, {'JMacnae': 1}),
#              'JArnaud': defaultdict(int,
#                          {'JDellinger': 1,
#                           'KHelbig': 1,
#                           'LIkelle': 1,
#                           'LThomsen': 2,
#                           'PRasolofosaon': 1}),
#              'AndyWard': defaultdict(int,
#                          {'FDayLewis': 1, 'RVersteeg': 1, 'TJohnson': 1}),
#              'MongLoke': defaultdict(int, {'TDahlin': 1}),
#              'RGerdes': defaultdict(int, {'SHendricks': 1, 'TKalscheuer': 1}),
#              'NOHara': defaultdict(int, {'WHinze': 1}),
#              'ShaokunCai': defaultdict(int, {'YHuang': 1, 'YapengYang': 1}),
#              'DGajewski': defaultdict(int,
#                          {'IPsenc': 1,
#                           'IPsencik': 1,
#                           'JianguoSun': 2,
#                           'KK': 1,
#                           'KMeier': 1,
#                           'KSommer': 1,
#                           'MBaykulov': 2,
#                           'MSpinner': 1,
#                           'NEttrich': 1,
#                           'RPatzig': 1,
#                           'SDummong': 2,
#                           'SergiusDell': 3,
#                           'THertweck': 1}),
#              'ChengYin': defaultdict(int,
#                          {'TingEnFan': 1, 'XiaolanLei': 1, 'ZhiguoWang': 1}),
#              'MPavlovic': defaultdict(int, {'RPrado': 1}),
#              'PGupta': defaultdict(int,
#                          {'SNiwas': 2, 'VGaur': 1, 'VinodGaur': 1}),
#              'CCalderonMac': defaultdict(int, {'MrinalSen': 1, 'PStoffa': 1}),
#              'DReynolds': defaultdict(int,
#                          {'KeithNunn': 1, 'MFoster': 1, 'SLewis': 1}),
#              'JKane': defaultdict(int, {'JSpence': 1}),
#              'KBeeney': defaultdict(int, {'RBrietzke': 1}),
#              'AHarding': defaultdict(int,
#                          {'GrahamKent': 1,
#                           'HAvendonk': 1,
#                           'IsaacKim': 1,
#                           'JOrcutt': 3,
#                           'MKappus': 1,
#                           'RDetrick': 1,
#                           'WHolbrook': 1}),
#              'RMellors': defaultdict(int, {'WTrainorGuitton': 1}),
#              'CHubscher': defaultdict(int,
#                          {'DGajewski': 1, 'KMeier': 1, 'SDummong': 1}),
#              'ALockwood': defaultdict(int, {'KerryKey': 1}),
#              'GyeChunCho': defaultdict(int,
#                          {'JSantamarina': 1, 'MinsuCha': 1}),
#              'EBooth': defaultdict(int,
#                          {'JTheriot': 1,
#                           'MNorris': 1,
#                           'PeterDuke': 1,
#                           'SStainsby': 1,
#                           'UAlgan': 1,
#                           'WGuyton': 1}),
#              'KerryKey': defaultdict(int,
#                          {'LeWan': 1,
#                           'MGlinsky': 1,
#                           'MHoversten': 1,
#                           'MZhdanov': 1,
#                           'MartinCuma': 1,
#                           'PStoffa': 1,
#                           'RMellors': 1,
#                           'RTatham': 1,
#                           'SConstable': 6,
#                           'SSingh': 1,
#                           'VBrown': 2,
#                           'WCumming': 1,
#                           'WTrainorGuitton': 1,
#                           'YuguoLi': 1}),
#              'ACarrasquilla': defaultdict(int,
#                          {'EUlugergerli': 1,
#                           'JLima': 1,
#                           'MMeju': 1,
#                           'MOliveira': 1,
#                           'SFontes': 1}),
#              'GCavuoto': defaultdict(int,
#                          {'IAlberico': 1,
#                           'LGiordano': 1,
#                           'MPunzo': 1,
#                           'NPelosi': 1,
#                           'SMazzola': 1,
#                           'VFiore': 1}),
#              'MAkhter': defaultdict(int,
#                          {'PMunoz': 1, 'SRaeuchle': 1, 'WAmbrose': 1}),
#              'DMcclure': defaultdict(int, {'PeterHood': 1}),
#              'GQuirogaGoode': defaultdict(int,
#                          {'JBatistaRodriguez': 1,
#                           'JCarcione': 1,
#                           'LGallardo': 1,
#                           'MPerezFlores': 1}),
#              'KaushikMaji': defaultdict(int, {'SAbeykoon': 1}),
#              'EDuveneck': defaultdict(int, {'MAlerini': 1, 'PBakker': 1}),
#              'JSass': defaultdict(int,
#                          {'JZiagos': 1, 'TMoses': 1, 'WWendt': 1}),
#              'RSingh': defaultdict(int, {'SVerma': 1, 'YSingh': 1}),
#              'IBucataru': defaultdict(int, {'MSlawinski': 1}),
#              'LBaise': defaultdict(int, {'MVanneste': 1, 'OLongva': 1}),
#              'AKurkjian': defaultdict(int,
#                          {'CMorris': 1,
#                           'HSchmidt': 1,
#                           'JMcclellan': 1,
#                           'JWhite': 1,
#                           'RCoates': 1,
#                           'SChang': 1,
#                           'SLang': 1,
#                           'TParks': 1}),
#              'JohnVoon': defaultdict(int,
#                          {'KYipCheong': 1,
#                           'MDarnet': 1,
#                           'MRosenquist': 1,
#                           'MatthewChoo': 1,
#                           'RPlessix': 1}),
#              'AGeiger': defaultdict(int,
#                          {'EKlingele': 1,
#                           'JVerdun': 1,
#                           'MCocard': 1,
#                           'MHalliday': 1,
#                           'RBayer': 1}),
#              'AAbubakar': defaultdict(int,
#                          {'ABelani': 1,
#                           'DAlumbaugh': 1,
#                           'GPan': 2,
#                           'GuangdongPan': 2,
#                           'GuozhongGao': 1,
#                           'JLiu': 1,
#                           'JRickett': 1,
#                           'JianguoLiu': 1,
#                           'LKnizhnerman': 3,
#                           'LLiang': 3,
#                           'MLi': 2,
#                           'MZaslavsky': 2,
#                           'MaokunLi': 3,
#                           'PeterBerg': 2,
#                           'SDavydycheva': 2,
#                           'THabashy': 17,
#                           'VDruskin': 5,
#                           'VSimoncini': 1,
#                           'WenyiHu': 4,
#                           'YLin': 1}),
#              'CRavazzoli': defaultdict(int,
#                          {'HHelle': 1,
#                           'JCarcione': 1,
#                           'JGomez': 1,
#                           'JRubino': 1,
#                           'JSantos': 2}),
#              'PHamilton': defaultdict(int, {'StephenPark': 1}),
#              'JKrebs': defaultdict(int,
#                          {'JRomberg': 1,
#                           'JonathanLiu': 1,
#                           'LorieBear': 1,
#                           'MDeffenbaugh': 1,
#                           'MLacasse': 1,
#                           'RMontelli': 1,
#                           'RNeelamani': 2,
#                           'SunwoongLee': 1}),
#              'MMadadi': defaultdict(int, {'MPervukhina': 1, 'OCollet': 1}),
#              'DXiao': defaultdict(int, {'HFang': 1, 'WLai': 1, 'WTsang': 1}),
#              'DMorris': defaultdict(int, {'PNelson': 1}),
#              'MMoorkamp': defaultdict(int, {'RHobbs': 1}),
#              'AAugustin': defaultdict(int,
#                          {'HMorrison': 1, 'KLee': 1, 'WKennedy': 1}),
#              'DBoutt': defaultdict(int,
#                          {'HTobin': 1, 'JennieCook': 1, 'LGoodwin': 1}),
#              'RAntonioCarpio': defaultdict(int, {'SMendezDelgado': 1}),
#              'DKomatitsch': defaultdict(int, {'JTromp': 2, 'RMartin': 2}),
#              'JGlover': defaultdict(int, {'MAlHusseini': 1}),
#              'DPatella': defaultdict(int, {'PMauriello': 2}),
#              'RChunduru': defaultdict(int, {'XiaomingTang': 1, 'ZZhang': 1}),
#              'AGusmeroli': defaultdict(int,
#                          {'BKulessa': 1,
#                           'CAxtell': 1,
#                           'RClark': 1,
#                           'TMurray': 1}),
#              'DThiel': defaultdict(int, {'IChant': 1}),
#              'DGoertz': defaultdict(int, {'RKnight': 1}),
#              'TBratton': defaultdict(int, {'ZMarzouki': 1}),
#              'JSpetzler': defaultdict(int,
#                          {'JTrampert': 1,
#                           'KarlHeinzWolf': 1,
#                           'OyvindKvam': 1,
#                           'RSnieder': 1}),
#              'MMiensopust': defaultdict(int,
#                          {'MMuller': 1, 'PShare': 1, 'SusanWebb': 1}),
#              'BGibson': defaultdict(int,
#                          {'GSutton': 1,
#                           'IChiHsu': 1,
#                           'KLarner': 4,
#                           'LHatton': 2,
#                           'MOdegard': 1,
#                           'RChambers': 1,
#                           'RWiggins': 1}),
#              'DMitchell': defaultdict(int,
#                          {'JMathewson': 1,
#                           'JiwuLin': 1,
#                           'RobHolt': 1,
#                           'SCharles': 1}),
#              'MCohen': defaultdict(int, {'PSen': 1}),
#              'DHinkley': defaultdict(int,
#                          {'JAnderson': 1,
#                           'JKrebs': 1,
#                           'MLacasse': 1,
#                           'RNeelamani': 1,
#                           'SunwoongLee': 1}),
#              'ChengfangYin': defaultdict(int,
#                          {'LiangangMa': 1,
#                           'MJiang': 1,
#                           'ShizhenKe': 1,
#                           'WeiXu': 1,
#                           'XiaowenLin': 1}),
#              'TRozsa': defaultdict(int, {'WBaillie': 1}),
#              'SoondukHong': defaultdict(int,
#                          {'TaeyoungHa': 2, 'WonsikKim': 1, 'YounghoCha': 1}),
#              'MDeszczPan': defaultdict(int, {'MWilt': 2}),
#              'IMoore': defaultdict(int,
#                          {'JMispel': 1,
#                           'JRobertsson': 1,
#                           'KOzdemir': 1,
#                           'MMajdanski': 1,
#                           'MThompson': 1,
#                           'MVassallo': 1,
#                           'RBisley': 1}),
#              'APires': defaultdict(int,
#                          {'ASilva': 1, 'JCurto': 1, 'NHarthill': 1}),
#              'PCosenza': defaultdict(int, {'PLeroy': 1}),
#              'JMitchell': defaultdict(int, {'RBolander': 1}),
#              'ASilva': defaultdict(int,
#                          {'CBarros': 1,
#                           'CCarneiro': 1,
#                           'JCurto': 1,
#                           'SFraser': 1}),
#              'JTomsStewart': defaultdict(int, {'LPaterson': 1, 'TMuller': 1}),
#              'GCumming': defaultdict(int, {'RClowes': 1}),
#              'MingqiuLuo': defaultdict(int,
#                          {'RuShanWu': 1, 'YongzhongWang': 1}),
#              'KLewallen': defaultdict(int, {'RDuren': 1, 'TommieRape': 1}),
#              'LiquanQiu': defaultdict(int,
#                          {'ShuangLiu': 1,
#                           'TianyouLiu': 1,
#                           'WenliGao': 1,
#                           'XiangyunHu': 1}),
#              'BBonner': defaultdict(int, {'JBerryman': 2, 'PBerge': 2}),
#              'JGazdag': defaultdict(int, {'PSguazzero': 1}),
#              'KainanWang': defaultdict(int, {'RGibson': 1, 'SireeshDadi': 1}),
#              'JinBaek': defaultdict(int, {'SangWanKim': 1}),
#              'APica': defaultdict(int,
#                          {'ATarantola': 4,
#                           'DCao': 1,
#                           'DTrezeguet': 1,
#                           'ECrase': 2,
#                           'ELanda': 1,
#                           'GRoeth': 1,
#                           'JDiet': 1,
#                           'JMcdonald': 1,
#                           'MJannane': 1,
#                           'MMendes': 1,
#                           'MNoble': 2,
#                           'MXie': 2,
#                           'RSnieder': 2,
#                           'SSingh': 1,
#                           'WBeydoun': 1,
#                           'ZKoren': 1}),
#              'SBelcher': defaultdict(int, {'TPratt': 1}),
#              'JStewart': defaultdict(int,
#                          {'KLewallen': 1,
#                           'LGodfrey': 1,
#                           'RDuren': 1,
#                           'TommieRape': 1}),
#              'BinWang': defaultdict(int,
#                          {'CMason': 3,
#                           'CRetaTang': 1,
#                           'DEpili': 2,
#                           'FAudebert': 1,
#                           'FaqiLiu': 1,
#                           'IJones': 1,
#                           'JLeveille': 1,
#                           'JeanJi': 1,
#                           'JunCai': 2,
#                           'KwangjinYoon': 1,
#                           'ManhongGuo': 2,
#                           'PGuillaume': 1,
#                           'SGajawada': 1,
#                           'VDirks': 1,
#                           'WWhiteside': 1,
#                           'XiansongZeng': 1,
#                           'XueningMa': 1,
#                           'YoungKim': 1,
#                           'ZhengZhengZhou': 1,
#                           'ZhimingLi': 2}),
#              'DaoliuWang': defaultdict(int,
#                          {'SamuelGray': 1, 'TianfeiZhu': 1, 'YZhang': 1}),
#              'GPurdy': defaultdict(int, {'MToksoz': 2, 'TimothyKeho': 1}),
#              'DLiang': defaultdict(int, {'DongWang': 1, 'DongliangLi': 1}),
#              'DDroschak': defaultdict(int, {'GGardner': 1, 'MWyllie': 1}),
#              'LihuaLiu': defaultdict(int,
#                          {'LitianHu': 1,
#                           'PSomerville': 1,
#                           'QingyuYou': 1,
#                           'TianyaoHao': 1,
#                           'XueleiLi': 1,
#                           'YuanWang': 1,
#                           'ZhiweiLi': 1}),
#              'JQuirein': defaultdict(int, {'JSchuelke': 1, 'NWarpinski': 1}),
#              'KhalidEssa': defaultdict(int, {'TElAraby': 1}),
#              'MSchneider': defaultdict(int, {'PTabeling': 1}),
#              ...})

# %% [markdown]
# ## Unique IDs
#
# Because of how GML works, we really need a unique ID for each author. So let's make a dictionary mapping each one to a unique integer:

# %%
aid = {k:i for i, k in enumerate(sorted(auth_nodes))}

# %%
aid
# Out:
# {'TScheuer': 8526,
#  'MKnoll': 5785,
#  'MPrasad': 5955,
#  'CReeves': 1299,
#  'DGoldberg': 1700,
#  'GSzurek': 3003,
#  'YiguangHu': 9439,
#  'AKuckes': 325,
#  'WBrisbin': 8845,
#  'YErlangga': 9318,
#  'SamuelKarp': 8178,
#  'BSternberg': 928,
#  'JiangLi': 4577,
#  'WLancaster': 8953,
#  'MGrech': 5682,
#  'HWang': 3400,
#  'KBube': 4767,
#  'MDehghannejad': 5604,
#  'NYadari': 6394,
#  'WGillingham': 8890,
#  'JSchleicher': 4327,
#  'POkoye': 6790,
#  'DRichter': 1896,
#  'WSchneider': 9025,
#  'PMcgowan': 6753,
#  'XingzhouLiu': 9256,
#  'RWatts': 7577,
#  'JLea': 4091,
#  'RobertBrod': 7645,
#  'CWalker': 1398,
#  'JSchmoker': 4328,
#  'DaleCox': 2019,
#  'GSimmons': 2992,
#  'RBailey': 7029,
#  'RaoulVajk': 7620,
#  'WentaoMu': 9135,
#  'CPower': 1289,
#  'LianghuiGuo': 5408,
#  'RGodfrey': 7197,
#  'DDrahos': 1642,
#  'KHambacker': 4815,
#  'DaniOr': 2020,
#  'JHaldorsen': 3967,
#  'DSmit': 1946,
#  'XiaoniuZeng': 9230,
#  'IBeresnev': 3558,
#  'DShillington': 1934,
#  'GuangjieWang': 3100,
#  'JWong': 4490,
#  'MotoakiSato': 6222,
#  'HWashburn': 3402,
#  'DBlair': 1564,
#  'DSunwall': 1960,
#  'APoikonen': 464,
#  'GerhardLukk': 3080,
#  'PLezaeta': 6730,
#  'HFang': 3196,
#  'XiaofengZou': 9217,
#  'SGuillon': 7861,
#  'JJohnson': 4045,
#  'MHatziemmanuel': 5711,
#  'AQuarteroni': 474,
#  'QingyunDiDi': 6995,
#  'JKoski': 4077,
#  'ABarthelmes': 55,
#  'CMorency': 1252,
#  'EwoutBerg': 2424,
#  'GBader': 2702,
#  'DAnderson': 1538,
#  'ShouguoYan': 8243,
#  'RThill': 7547,
#  'GRice': 2963,
#  'KFu': 4809,
#  'DMagnier': 1798,
#  'WMcguinness': 8971,
#  'XiujuanWang': 9270,
#  'JPatch': 4227,
#  'HArnetzl': 3137,
#  'CCamerlynck': 1076,
#  'LBorgman': 5097,
#  'RMadariaga': 7341,
#  'HVillinger': 3397,
#  'PGuerendel': 6643,
#  'DGough': 1703,
#  'CVaughan': 1390,
#  'MHosseinpour': 5727,
#  'DKinman': 1760,
#  'RRechtien': 7448,
#  'JDunbar': 3866,
#  'SWetterich': 8147,
#  'AChaturvedi': 121,
#  'KateHine': 5022,
#  'SAltaner': 7712,
#  'ASrivastava': 546,
#  'KLau': 4874,
#  'MBuonora': 5562,
#  'JLeveille': 4103,
#  'BSeymour': 914,
#  'ZhengpingLiu': 9593,
#  'SReynolds': 8054,
#  'STerry': 8121,
#  'LBerryman': 5089,
#  'AHusseiny': 269,
#  'QianFang': 6973,
#  'MAmmerman': 5481,
#  'CVuillermoz': 1397,
#  'AGilmour': 222,
#  'GZaalbergMetselaar': 3045,
#  'SUpadhyay': 8135,
#  'ECaspari': 2139,
#  'RHilst': 7248,
#  'ABeck': 63,
#  'EmilyFay': 2404,
#  'JAllsop': 3694,
#  'MBudny': 5561,
#  'BNielsen': 873,
#  'CanYang': 1428,
#  'ShengxiongYang': 8226,
#  'GYadav': 3042,
#  'JKhazanehdari': 4064,
#  'WPreeg': 8999,
#  'HTsu': 3388,
#  'RongSongJih': 7668,
#  'TDutta': 8370,
#  'JCarvalho': 3784,
#  'TProbert': 8505,
#  'GNover': 2925,
#  'TonglinLi': 8640,
#  'JohnBeck': 4666,
#  'AndrejBona': 675,
#  'RRenaut': 7453,
#  'MichaelReed': 6191,
#  'BRussell': 906,
#  'DKumar': 1769,
#  'WHeap': 8910,
#  'YKiselev': 9334,
#  'MSafar': 5991,
#  'RNolting': 7397,
#  'HEmmerich': 3193,
#  'OPedersen': 6486,
#  'MBerry': 5519,
#  'GVoorhis': 3025,
#  'AKuvshinov': 330,
#  'TGresham': 8391,
#  'JMacelwane': 4127,
#  'PLeonide': 6727,
#  'DAdkinsHeljeson': 1529,
#  'CDresbach': 1118,
#  'MBeiki': 5512,
#  'DKouri': 1767,
#  'KGomes': 4812,
#  'HZhang': 3424,
#  'GGribler': 2820,
#  'RHagemann': 7223,
#  'PeterVail': 6940,
#  'HauWeiZhou': 3464,
#  'RJanicke': 7278,
#  'RSteinhoff': 7518,
#  'PDoulgeris': 6605,
#  'PeimingLi': 6920,
#  'MaartenHoop': 6136,
#  'KDieter': 4794,
#  'CVuik': 1396,
#  'DRhodes': 1895,
#  'LDemkowicz': 5133,
#  'KSharma': 4951,
#  'KAytun': 4748,
#  'SRaikes': 8044,
#  'XiangDuDu': 9188,
#  'WKohler': 8947,
#  'WAdams': 8823,
#  'LPorter': 5279,
#  'YAltundas': 9299,
#  'CSicking': 1340,
#  'RGraebner': 7204,
#  'RFrese': 7179,
#  'HAhmed': 3127,
#  'AWendler': 617,
#  'AGregory': 237,
#  'BGelchinsky': 791,
#  'DavidHart': 2035,
#  'RBenson': 7048,
#  'OLovera': 6477,
#  'MKrohn': 5793,
#  'PingAn': 6954,
#  'EStatham': 2350,
#  'ZhenYang': 9589,
#  'LMorrison': 5245,
#  'SWitsker': 8155,
#  'JungkyunShin': 4727,
#  'EOblow': 2299,
#  'JLymburner': 4124,
#  'CHouser': 1175,
#  'MToksoz': 6075,
#  'TVilhelmsen': 8551,
#  'BinLiu': 988,
#  'MAlatorreZamora': 5467,
#  'JGrant': 3953,
#  'DAdams': 1528,
#  'BjarneNost': 1000,
#  'YSripanich': 9374,
#  'AKenyon': 304,
#  'JBible': 3729,
#  'BinghengYuan': 996,
#  'JoostNeut': 4693,
#  'RLangan': 7321,
#  'SSavazzi': 8078,
#  'WWensheng': 9065,
#  'JianjunZeng': 4589,
#  'ESchwarz': 2341,
#  'SCheng': 7776,
#  'ALegchenko': 341,
#  'HKaraoglu': 3252,
#  'AVladimirsky': 606,
#  'SixinLiu': 8273,
#  'GHenry': 2836,
#  'THertweck': 8407,
#  'SChung': 7782,
#  'DEpili': 1663,
#  'JayKwon': 4538,
#  'RGoodell': 7202,
#  'HWerner': 3406,
#  'BGutenberg': 805,
#  'WCurry': 8866,
#  'WShepard,': 9031,
#  'RobinBell': 7660,
#  'RCatchings': 7097,
#  'WaiKinChan': 9081,
#  'RMeek': 7362,
#  'JGillin': 3941,
#  'MMareschal': 5840,
#  'WLowrie': 8960,
#  'EdwardSalo': 2396,
#  'JShanks': 4344,
#  'EWinniski': 2385,
#  'PSouthwick': 6854,
#  'MJeannin': 5744,
#  'SGelinsky': 7840,
#  'YongenCai': 9464,
#  'SGreenhalgh': 7857,
#  'JFokkema': 3908,
#  'WRietveld': 9004,
#  'HEicken': 3190,
#  'MQueisser': 5962,
#  'MRivest': 5981,
#  'SPeacock': 8022,
#  'ABaggeroer': 42,
#  'JStewart': 4394,
#  'VKumar': 8740,
#  'WeiXu': 9103,
#  'NNajjar': 6346,
#  'LBaradello': 5079,
#  'CMiller': 1250,
#  'AMacarthur': 363,
#  'YingJieGao': 9446,
#  'SSharafeldin': 8088,
#  'JTaranik': 4411,
#  'PTesch': 6875,
#  'AForster': 195,
#  'EWescott': 2383,
#  'NguyenPham': 6410,
#  'MKingston': 5781,
#  'MPedersen': 5927,
#  'NSaito': 6367,
#  'AFraser': 200,
#  'JensMunk': 4552,
#  'BShammas': 915,
#  'SMisra': 7986,
#  'GPapanicolaou': 2939,
#  'SChristensen': 7781,
#  'ELanda': 2243,
#  'MDoyle': 5623,
#  'XiansongZeng': 9199,
#  'IvanP': 3677,
#  'SHornbostel': 7888,
#  'AMiniussi': 399,
#  'FHilterman': 2515,
#  'ILongman': 3605,
#  'PAdler': 6513,
#  'PBerg': 6534,
#  'ANautiyal': 417,
#  'EBaysal': 2118,
#  'IMorozov': 3617,
#  'CHyslop': 1185,
#  'HBroome': 3155,
#  'DBarnes': 1549,
#  'SJabbari': 7904,
#  'ABrown': 96,
#  'FSciraScappuzzo': 2620,
#  'FAndreasi': 2438,
#  'JWashburne': 4466,
#  'GCheng': 2749,
#  'RamaRao': 7615,
#  'PHuddleston': 6675,
#  'WBandy': 8833,
#  'OOncken': 6483,
#  'KBurkart': 4769,
#  'LKonstantaki': 5199,
#  'MSkold': 6028,
#  'WankuiGuo': 9086,
#  'CKean': 1201,
#  'RHassan': 7234,
#  'HPickett': 3329,
#  'HTewari': 3378,
#  'LWhite': 5353,
#  'PRomig': 6819,
#  'APrice': 469,
#  'RBeach': 7042,
#  'HLynn,': 3279,
#  'AnaAbad': 671,
#  'MGutierrez': 5693,
#  'GJonsson': 2860,
#  'AVerdel': 598,
#  'IMuller': 3619,
#  'ALundsgaard': 361,
#  'ARatcliffe': 481,
#  'HKazemeini': 3256,
#  'MTaner': 6063,
#  'MarcAndreChen': 6152,
#  'AClark': 130,
#  'RCarroll': 7095,
#  'KSegeth': 4947,
#  'PGoode': 6638,
#  'BSiemon': 918,
#  'LNicoletis': 5255,
#  'QZhou': 6970,
#  'MCampillo': 5567,
#  'IKoulakov': 3599,
#  'GWilson': 3039,
#  'DBhattacharjya': 1558,
#  'LGochioco': 5164,
#  'GDiaferia': 2772,
#  'RadimCiz': 7612,
#  'DBlankenship': 1565,
#  'DBaldwin': 1546,
#  'GRobertson': 2967,
#  'JKouba': 4079,
#  'CBeckett': 1048,
#  'PSteeghs': 6858,
#  'TingEnFan': 8621,
#  'IReddy': 3637,
#  'KKlaus': 4859,
#  'PHaggerty': 6649,
#  'AZemanian': 639,
#  'LongweiChen': 5433,
#  'KLange': 4872,
#  'TMercer': 8467,
#  'KHayley': 4820,
#  'GAsquith': 2697,
#  'SKarimpouli': 7919,
#  'EAnderson': 2102,
#  'EtienneRey': 2419,
#  'HRomero': 3339,
#  'SNicoletis': 8006,
#  'MarkNg': 6157,
#  'JFinol': 3904,
#  'JKellogg': 4059,
#  'OEsser': 6449,
#  'MTempleton': 6067,
#  'HuJin': 3517,
#  'ThomasWest': 8601,
#  'LMartino': 5230,
#  'RMjelde': 7375,
#  'RobertLey': 7648,
#  'XuJi': 9276,
#  'CMacbeth': 1230,
#  'LuisRijo': 5449,
#  'WLutter': 8962,
#  'APerelberg': 451,
#  'NCanitez': 6258,
#  'HAshraf': 3139,
#  'JiaqiYang': 4603,
#  'DMarchant': 1801,
#  'NGodfrey': 6296,
#  'GGulmon': 2824,
#  'MMeres': 5864,
#  'AAhmadifard': 9,
#  'THall': 8398,
#  'MatthewJosh': 6170,
#  'BRao': 892,
#  'AMordret': 405,
#  'JLiard': 4108,
#  'XiaoLi': 9204,
#  'ADeighan': 149,
#  'KwangjinYoon': 5060,
#  'WGibbons': 8889,
#  'XueyingLi': 9288,
#  'RMoberly': 7376,
#  'FDrossaert': 2483,
#  'VBakulin': 8684,
#  'BSatpathy': 909,
#  'RHaddon': 7222,
#  'DeshuXu': 2063,
#  'ZhihuiXue': 9610,
#  'RFernandez': 7164,
#  'ChenLi': 1460,
#  'DRevelo': 1893,
#  'YandongLi': 9396,
#  'TRichards': 8514,
#  'JeongminYu': 4556,
#  'ACrosta': 139,
#  'DaveLane': 2029,
#  'EGonzalo': 2198,
#  'StuartHall': 8299,
#  'ADuijndam': 167,
#  'MProvart': 5956,
#  'DPhillips': 1871,
#  'VFiore': 8718,
#  'JDumay': 3865,
#  'VVavrycuk': 8805,
#  'VLabson': 8741,
#  'EToewe': 2364,
#  'SGupta': 7863,
#  'WHeigl': 8911,
#  'GPerez': 2945,
#  'JSkinner': 4369,
#  'TongBai': 8634,
#  'MathiasFink': 6167,
#  'FSantos': 2615,
#  'HJaramillo': 3246,
#  'MikeBerg': 6201,
#  'MPieuchot': 5937,
#  'GDuncan': 2777,
#  'WHorner': 8922,
#  'JPowell': 4255,
#  'GFlanagan': 2792,
#  'GHolstrom': 2848,
#  'YKaida': 9331,
#  'LingshunMeng': 5423,
#  'DAndreis': 1539,
#  'EBlondeau': 2128,
#  'EForte': 2180,
#  'SongtingLuo': 8279,
#  'BHoffe': 816,
#  'HuiWang': 3534,
#  'MGregotski': 5686,
#  'MHauser': 5712,
#  'QianZhao': 6974,
#  'CBates': 1042,
#  'JSheehan': 4349,
#  'EHerrin': 2209,
#  'GuangQi': 3098,
#  'WSalisbury': 9017,
#  'FRenalier': 2602,
#  'CCorry': 1102,
#  'AFerretti': 190,
#  'ZGuanQuan': 9537,
#  'HCruts': 3176,
#  'ZXiong': 9562,
#  'JBerryhill': 3726,
#  'HBanta': 3143,
#  'JKapoor': 4051,
#  'WBurnett': 8847,
#  'KNakayama': 4907,
#  'DavidPai': 2041,
#  'EOrellana': 2301,
#  'IPanea': 3628,
#  'JKnight': 4071,
#  'SCalkin': 7758,
#  'EMaeland': 2262,
#  'DGerovska': 1691,
#  'WAlemie': 8826,
#  'ShujieXu': 8252,
#  'ABenMenahem': 70,
#  'JCarter': 3783,
#  'HHelle': 3223,
#  'JAllingham': 3693,
#  'MWoodward': 6118,
#  'KKaplin': 4845,
#  'NiuWei': 6422,
#  'COfficer': 1265,
#  'WSauck': 9020,
#  'AGallois': 207,
#  'CEngland': 1125,
#  'MRauth': 5966,
#  'BMcadoo': 855,
#  'RBrewer': 7075,
#  'LAmundsen': 5068,
#  'SFraiha': 7830,
#  'DHannay': 1718,
#  'MVoltolini': 6100,
#  'WFarren': 8880,
#  'ShenWang': 8218,
#  'ASauter': 513,
#  'AnningHou': 691,
#  'RFerrari': 7165,
#  'JSimmons': 4362,
#  'WJamison': 8931,
#  'PHarben': 6656,
#  'RPlessix': 7432,
#  'DWantland': 1989,
#  'NHargreaves': 6306,
#  'AAsnaashari': 36,
#  'BaiyaoRuan': 966,
#  'NNAtienza': 6344,
#  'MDabas': 5595,
#  'GregoryEly': 3095,
#  'PNyegaard': 6787,
#  'VDruskin': 8714,
#  'HWinkler': 3413,
#  'SamGray': 8172,
#  'ATakahata': 564,
#  'MGraca': 5678,
#  'DaxingWang': 2046,
#  'DNichols': 1850,
#  'UDikmen': 8659,
#  'NKamath': 6320,
#  'AltonReid': 665,
#  'EArmadillo': 2107,
#  'WPritchett': 9000,
#  'LThomas': 5327,
#  'LeeHunt': 5379,
#  'ABasokur': 56,
#  'WLupinacci': 8961,
#  'TerrellDaw': 8582,
#  'AWharton': 618,
#  'KevinUng': 5042,
#  'WStone': 9047,
#  'DLeiphart': 1780,
#  'SGesbert': 7843,
#  'MJacoby': 5741,
#  'ZhongLi': 9626,
#  'ADalby': 142,
#  'MPorsani': 5949,
#  'RichardRay': 7634,
#  'AGisolf': 223,
#  'MSugihara': 6051,
#  'FZyserman': 2647,
#  'JKarcher': 4052,
#  'MPinto': 5939,
#  'WeinanWang': 9113,
#  'JSypniewski': 4403,
#  'LMyer': 5250,
#  'JCombs': 3804,
#  'MTuttle': 6082,
#  'WDebski': 8870,
#  'ZDanes': 9530,
#  'AMazzotti': 387,
#  'AVolker': 607,
#  'ZengliDuDu': 9570,
#  'ARoberts': 496,
#  'PLailly': 6716,
#  'MAldana': 5469,
#  'LAltissimo': 5067,
#  'TGamble': 8383,
#  'ETrevino': 2369,
#  'MyungLee': 6231,
#  'AlfonsoI': 659,
#  'XRefunjol': 9177,
#  'SAssous': 7719,
#  'CCollins': 1096,
#  'CWarren': 1400,
#  'JZiagos': 4510,
#  'LIvanhoe': 5186,
#  'DMcconnell': 1812,
#  'REvans': 7158,
#  'LHowell': 5182,
#  'ADaynes': 148,
#  'DDubucq': 1646,
#  'KSabra': 4938,
#  'SZhang': 8168,
#  'KaiyunLuo': 5011,
#  'WMulder': 8983,
#  'RNisle': 7395,
#  'YMatsubara': 9348,
#  'RReynolds': 7455,
#  'TRekola': 8513,
#  'ZhenXingYao': 9588,
#  'ALeblanc': 339,
#  'JKotcher': 4078,
#  'MDiament': 5611,
#  'FGilbert': 2502,
#  'NSleen': 6373,
#  'QinzhongMa': 6997,
#  'MSchoenberg': 6012,
#  'AMalinverno': 373,
#  'ECassano': 2140,
#  'JFitter': 3906,
#  'TFurumura': 8382,
#  'FAngona': 2439,
#  'JHaugen': 3981,
#  'DBahjat': 1544,
#  'SShope': 8093,
#  'InKyCho': 3666,
#  'IKoch': 3597,
#  'EThiel': 2363,
#  'HPascal': 3322,
#  'SimoneRe': 8268,
#  'AZohdy': 643,
#  'SCardimona': 7761,
#  'EMercerat': 2282,
#  'ZhenglinPei': 9592,
#  'RobertOtis': 7651,
#  'JODonnell': 4204,
#  'OAlhagan': 6434,
#  'ATaghan': 563,
#  'JonathanLiu': 4689,
#  'GrantGist': 3092,
#  'WGreen': 8896,
#  'ChengliangFan': 1470,
#  'ACurtis': 141,
#  'MOhrnberger': 5912,
#  'MZhdanov': 6129,
#  'ABhuyian': 78,
#  'MGrbovic': 5681,
#  'VMenichetti': 8749,
#  'MJegen': 5745,
#  'ABarry': 53,
#  'LanboLiu': 5365,
#  'KKadinskyCade': 4843,
#  'JieWang': 4611,
#  'APidlisecky': 458,
#  'JSharpe': 4347,
#  'CMoustier': 1256,
#  'WRivers': 9007,
#  'CGreen': 1149,
#  'TChichinina': 8348,
#  'ATehrani': 572,
#  'CSaynWittgenstein': 1322,
#  'TLautzenhiser': 8444,
#  'CHayward': 1161,
#  'FMantlik': 2561,
#  'VMurphy': 8755,
#  'CJanna': 1191,
#  'MWilt': 6116,
#  'AKobrunov': 313,
#  'RobertBaum': 7642,
#  'LZimmerman': 5364,
#  'MRichards': 5977,
#  'DDondurur': 1636,
#  'MHewitt': 5716,
#  'FCiabarri': 2469,
#  'SSilliman': 8095,
#  'DKao': 1753,
#  'SMouritsen': 7995,
#  'ChunHuiHou': 1505,
#  'ADevaney': 155,
#  'TBurkhart': 8340,
#  'KCoyner': 4784,
#  'KCox': 4783,
#  'HDeng': 3179,
#  'SRangarajan': 8048,
#  'VShabro': 8779,
#  'XinpingCai': 9260,
#  'AmosNur': 670,
#  'DJayawickreme': 1745,
#  'GFitzgerald': 2790,
#  'ZhinaLi': 9620,
#  'EarleOwen': 2395,
#  'MLarson': 5805,
#  'JFriedberg': 3919,
#  'SDeregowski': 7802,
#  'AHanssen': 249,
#  'QYanFu': 6968,
#  'NSundararajan': 6378,
#  'LDewey': 5135,
#  'MSalisbury': 5996,
#  'LBotterJensen': 5099,
#  'HMarch': 3286,
#  'BaofengTian': 970,
#  'RRaffalovich': 7442,
#  'MMiller': 5870,
#  'CBaumann': 1044,
#  'ALeykam': 350,
#  'RWildman': 7592,
#  'LSkopintseva': 5307,
#  'FrankTsai': 2672,
#  'DJupp': 1751,
#  'MClennell': 5584,
#  'WHawes': 8909,
#  'JEnnisKing': 3885,
#  'XiaomengLi': 9227,
#  'CReine': 1301,
#  'GTurkiyyah': 3013,
#  'LPimienta': 5277,
#  'JMoore': 4178,
#  'ZaitianMa': 9568,
#  'CDennis': 1112,
#  'THildenbrand': 8408,
#  'KMeier': 4896,
#  'JDvorkin': 3874,
#  'GCooper': 2760,
#  'ESkomal': 2345,
#  'SRigobert': 8057,
#  'JamesWait': 4529,
#  'DJohnson': 1747,
#  'OFriberg': 6452,
#  'RPatzig': 7414,
#  'JCharbucinski': 3791,
#  'SCao': 7760,
#  'CRushlow': 1309,
#  'TAckman': 8309,
#  'WUrquhart': 9055,
#  'LBrossard': 5103,
#  'RichardWold': 7637,
#  'BAlmqvist': 711,
#  'IRavve': 3636,
#  'RNolenHoeksema': 7396,
#  'CIrons': 1186,
#  'EDougherty': 2154,
#  'DKnowlton': 1763,
#  'MGuddati': 5689,
#  'GBambakidis': 2705,
#  'FernandoDias': 2667,
#  'SCheckles': 7773,
#  'CEsmersoy': 1127,
#  'EKelly': 2227,
#  'RDumont': 7142,
#  'RGreaves': 7208,
#  'VCourtillot': 8705,
#  'DSecord': 1926,
#  'BTraub': 940,
#  'NVergo': 6388,
#  'JPujol': 4263,
#  'TLowry': 8452,
#  'THenyey': 8405,
#  'StefanBunz': 8287,
#  'JRezaie': 4277,
#  'TCollins': 8351,
#  'RStein': 7517,
#  'KCohick': 4780,
#  'HMaurer': 3290,
#  'JHannila': 3974,
#  'MKriegel': 5792,
#  'YingjieGao': 9450,
#  'NJacobsen': 6314,
#  'FJonard': 2528,
#  'AThompson': 574,
#  'EDeridder': 2153,
#  'PRaab': 6807,
#  'AReitan': 488,
#  'LBrown': 5104,
#  'ChunlingWu': 1512,
#  'ByungKooHyun': 1021,
#  'ArmandoSena': 699,
#  'HungTran': 3542,
#  'RGunn': 7217,
#  'EMercado': 2281,
#  'RHerrmann': 7243,
#  'DBonar': 1570,
#  'RPittman': 7430,
#  'DLennox': 1781,
#  'RStacey': 7514,
#  'HSteeb': 3371,
#  'RShaw': 7481,
#  'JochenKamm': 4662,
#  'FGuspi': 2506,
#  'APayas': 450,
#  'INovara': 3622,
#  'RachelWood': 7611,
#  'SWilliamsStroud': 8153,
#  'TODonnell': 8488,
#  'OAbraham': 6427,
#  'PCorubolo': 6581,
#  'BSarma': 908,
#  'ALebedev': 338,
#  'KOwusu': 4919,
#  'AMisbah': 400,
#  'CKimball': 1206,
#  'JGeorge': 3937,
#  'PMihalffy': 6763,
#  'SorayaTuma': 8283,
#  'MButton': 5564,
#  'NTyler': 6385,
#  'RPorter': 7435,
#  'LUhrig': 5338,
#  'VZitko': 8812,
#  'RMorin': 7383,
#  'TEdrington': 8371,
#  'BTravis': 941,
#  'MPeszynska': 5934,
#  'ThomasKean': 8595,
#  'DEllis': 1660,
#  'MGoupillot': 5677,
#  'MWathelet': 6102,
#  'DPoley': 1874,
#  'BingbingSun': 995,
#  'HBrown': 3156,
#  'LSlichter': 5309,
#  'JMacnae': 4129,
#  'AWitten': 623,
#  'CaCa': 1422,
#  'YIlyin': 9328,
#  'JeanRoy': 4544,
#  'LMeister': 5237,
#  'JBedenbender': 3716,
#  'JSonnad': 4378,
#  'RPhinney': 7427,
#  'KHedlin': 4822,
#  'YoungSaeKong': 9477,
#  'ATarasov': 570,
#  'GMcguckin': 2900,
#  'JAllenou': 3692,
#  'YanhuaYuan': 9408,
#  'PeterMora': 6938,
#  'EEckhardt': 2157,
#  'VBrown': 8694,
#  'FJagodits': 2525,
#  'MLankston': 5803,
#  'CNotfors': 1262,
#  'DGlaser': 1698,
#  'HPaasche': 3321,
#  'DNyman': 1853,
#  'AGorman': 232,
#  'IBruner': 3565,
#  'GCaillet': 2739,
#  'WBarrash': 8834,
#  'RGagne': 7184,
#  'KAktas': 4740,
#  'VDimri': 8711,
#  'WCampbell': 8850,
#  'JCrepaldi': 3816,
#  'XixiangZhou': 9274,
#  'MTrani': 6078,
#  'DCooke': 1613,
#  'EZinni': 2393,
#  'DMuhll': 1839,
#  'GuanWang': 3097,
#  'XiaoxiaXu': 9235,
#  'ATutuncu': 586,
#  'TomNye': 8631,
#  'SangWanKim': 8183,
#  'JacksonOdum': 4516,
#  'TongningYang': 8642,
#  'RolandPail': 7663,
#  'PAkerberg': 6515,
#  'AMillett': 398,
#  'KKlemMusatov': 4860,
#  'MRonczka': 5984,
#  'RParker': 7412,
#  'MPorte': 5950,
#  'NDebeglia': 6275,
#  'JTromp': 4432,
#  'WChew': 8858,
#  'JDunkin': 3867,
#  'JLorenzo': 4117,
#  'RHerrera': 7242,
#  'MMajdanski': 5828,
#  'PDehlinger': 6592,
#  'GDotti': 2773,
#  'AlfredDyck': 660,
#  'CBergeron': 1052,
#  'RWard': 7573,
#  'SZargari': 8167,
#  'PFowler': 6620,
#  'NBenyamin': 6245,
#  'UAlbertin': 8651,
#  'AlfredoLeon': 663,
#  'JBarongo': 3709,
#  'ZShuLun': 9560,
#  'ZhiliHe': 9614,
#  'MFitzpatrick': 5650,
#  'DDroege': 1644,
#  'PWilliamson': 6904,
#  'TerryLee': 8583,
#  'SOliveira': 8014,
#  'BDashwood': 767,
#  'ChangryolKim': 1441,
#  'XiaosanZhu': 9232,
#  'WarrenWood': 9090,
#  'PShamsipour': 6839,
#  'HongbingLi': 3496,
#  'AKotz': 319,
#  'ALogachev': 356,
#  'MAmrouche': 5482,
#  'WSandham': 9018,
#  'AOelke': 430,
#  'RNorris': 7399,
#  'JianXing': 4573,
#  'AStarr': 550,
#  'MKiehn': 5777,
#  'DGendzwill': 1689,
#  'JFitton': 3907,
#  'YRicard': 9362,
#  'SMittal': 7988,
#  'ZhanxiangHe': 9576,
#  'KMatson': 4890,
#  'DelmanLee': 2052,
#  'SHummerMiller': 7897,
#  'SGutjahr': 7864,
#  'CarlosTome': 1431,
#  'JCarcione': 3780,
#  'AJunger': 286,
#  'SKlemperer': 7928,
#  'YAshida': 9303,
#  'WCarey': 8851,
#  'ZGuang': 9538,
#  'VNagassar': 8756,
#  'HButtlar': 3162,
#  'JHedditch': 3990,
#  'KErickson': 4802,
#  'AMurthy': 409,
#  'WFilipo': 8881,
#  'RVayavur': 7563,
#  'JingyeLi': 4646,
#  'LBertelli': 5090,
#  'GPalacky': 2935,
#  'RBurnett': 7085,
#  'RGodson': 7198,
#  'YSanada': 9367,
#  'AlfredWolf': 662,
#  'AUstra': 589,
#  'WeiKang': 9094,
#  'HCollier': 3173,
#  'JDuval': 3873,
#  'PeiJuShih': 6919,
#  'GLoper': 2885,
#  'PGolodoniuc': 6636,
#  'WMurray': 8986,
#  'IAbakumov': 3551,
#  'BSpies': 926,
#  'ABarnhoorn': 51,
#  'DDougherty': 1639,
#  'BLipinski': 846,
#  'RichardFox': 7630,
#  'ADhemaied': 157,
#  'JLyrio': 4126,
#  'KennethBube': 5035,
#  'CSingh': 1345,
#  'JuanGarc': 4708,
#  'JorgenPihl': 4696,
#  'CTarlowski': 1370,
#  'MSchafer': 6006,
#  'DRaymer': 1889,
#  'JSchuelke': 4332,
#  'MChmiel': 5579,
#  'KVerwer': 4983,
#  'PMudra': 6774,
#  'ADasios': 143,
#  'PYogeshwar': 6911,
#  'LKnauer': 5196,
#  'LEsteban': 5151,
#  'ILonardelli': 3604,
#  'JAjoFranklin': 3686,
#  'FHerrmann': 2514,
#  'MBecquey': 5509,
#  'SSzasz': 8118,
#  'DWhite': 1996,
#  'PBuller': 6551,
#  'CSantos': 1316,
#  'GMcneice': 2902,
#  'JPesicek': 4236,
#  'DWerthmuller': 1994,
#  'MCardiff': 5569,
#  'PMunoz': 6777,
#  'LGerdes': 5161,
#  'JIrving': 4036,
#  'EBazelaire': 2119,
#  'EvertSlob': 2423,
#  'SThiel': 8124,
#  'SHeaps': 7877,
#  'TLochbuhler': 8450,
#  'AshwaniDev': 701,
#  'JHiggins': 4003,
#  'JMorten': 4183,
#  'TStenvold': 8537,
#  'PPetrov': 6801,
#  'SSingh': 8097,
#  'IZietz': 3660,
#  'RBrod': 7078,
#  'OAhmed': 6430,
#  'GPonzini': 2951,
#  'JohnNafe': 4682,
#  'OAkalin': 6432,
#  'XueweiLiu': 9287,
#  'PhilAnno': 6942,
#  'JTrier': 4431,
#  'PMazumdar': 6748,
#  'CHuang': 1180,
#  'MChlamtac': 5578,
#  'ARapolla': 480,
#  'LYunHe': 5360,
#  'GabrielChao': 3050,
#  'SLim': 7955,
#  'ACorreia': 137,
#  'TGunther': 8395,
#  'CMueller': 1258,
#  'SamuelKatz': 8179,
#  'TLokajicek': 8451,
#  'FPress': 2597,
#  'MAllison': 5477,
#  'HSantos': 3351,
#  'QingqingLi': 6988,
#  'ABarkov': 49,
#  'JHalpenny': 3968,
#  'PRicarte': 6813,
#  'HLiang': 3274,
#  'TRedshaw': 8511,
#  'CMeyer': 1248,
#  'BCouzensSchultz': 762,
#  'MHoversten': 5729,
#  'SHansen': 7872,
#  'MBest': 5521,
#  'TElkins': 8374,
#  'MPattantyusA': 5923,
#  'APrugger': 471,
#  'NThompson': 6382,
#  'JClough': 3799,
#  'StephenChiu': 8293,
#  'HWarren': 3401,
#  ...}

# %% [markdown]
# ## Build GML file parts
#
# Now we can iterate over the nodes to build up the node-list part of the GML file:

# %%
import itertools
import numpy as np

node_template = """  node [
    id {}
    label "{}"
  ]
"""

auth_node_text = ''

for auth in auth_nodes:
    auth_node_text += node_template.format(aid[auth], auth)
    
print(auth_node_text[:202])
# Out:
#   node [
#     id 1299
#     label "CReeves"
#   ]
#   node [
#     id 7736
#     label "SBiehler"
#   ]
#   node [
#     id 8178
#     label "SamuelKarp"
#   ]
#   node [
#     id 4327
#     label "JSchleicher"
#   ]
#   node [
#     i

# %% [markdown]
# And a similar thing for the edge list part:

# %%
edge_template = """  edge [
    source {}
    target {}
    value {}
  ]
"""

auth_edge_text = ''

for auth, coauths in auth_edges.items():
    for coauth, value in coauths.items():
        auth_edge_text += edge_template.format(aid[auth], aid[coauth], value)

print(auth_edge_text[:226])
# Out:
#   edge [
#     source 5785
#     target 7302
#     value 1
#   ]
#   edge [
#     source 5785
#     target 8861
#     value 4
#   ]
#   edge [
#     source 5785
#     target 8421
#     value 1
#   ]
#   edge [
#     source 5785
#     target 6821
#     value 3

# %% [markdown]
# ## Write out file

# %%
gml_template = """Creator "Matt Hall and SEG"
graph [
  comment "Coauthorship graph, SEG Geophysics"
  directed 0
  
{}{}
]
"""

auth_gml_text = gml_template.format(auth_node_text, auth_edge_text)

# %%
with open('data/coauthors.gml', 'w', encoding='ascii') as f:
    f.write(auth_gml_text)

# %% [markdown]
# Now we can go off and explore this dataset in [Coauthor_network_analysis.ipynb](Coauthor_network_analysis.ipynb).

# %% [markdown]
# <hr />
#
# &copy; 2017 Agile Scientific, licensed under CC-BY (text) and Apache 2.0 (code)
